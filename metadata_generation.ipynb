# %% [markdown]
# Open Project: Automated Metadata Generator (MARS)
# Submitted by : Yojit Goyal (22324028)

# %% [markdown]
# IMPORTANT NOTE:
# I have done the whole process step by step in different cells of the ipynb file and then combined all the steps in the last cell block of the ipynb code. You can run the last cell block to generate the local or public url of the interface of the automated metadata generator. Make sure to run the last code cell block to generate a new link for the interface metadata generator.

# %% [markdown]
# Approach used in the Project:
# 1. In the problem statement we are told that the files may be of the format txt, docx or pdf. For docx and txt files we can directly extract text without doing ocr as they contain text in digitally recognizable format.
# 2. For pdf files, we might have to do ocr as they may be a scanned pdf and may not contain the text in digitally recognisable format. So we are using a ocr_fallback_threshold where if the text extracted from the page of pdf is less than a particular threshold (ocr_fallback_threshold) it would mean that the page is scanned and ocr is needed. Otherwise we would directly extract all the text. We are doing ocr for all the pages as it will slow down the process of metadata generation. If there is a little text present in the pdf in form of image elements we can skip them as it won't matter in our overall goal of semantically rich metadata generation.
# 3. Now since most llms have input token limit, so we cannot give the whole pdf to the llm for metadata generation. So instead we'll be first chunking the pdf, and using the llm to summarize each chunk while preserving the metadata and then combine the summaries of all the chunks.
# 4. We are also using RAG in our approach. Once the combined summary has been generated we will give the combined summary to the llm telling it to generate relevant questions that can be answered using the pdf and can be used in RAG to retrieve chunks which will be relevant for metadata generation.
# 5. Now we are giving the chunks retrieved from RAG along with the combined_summary to the llm for metadata generation. And we are getting the metadata as the final output.

# %%
##Identifying the file to find out if OCR is needed or not
import os


def get_file_type_safely(file_path):
    _ , extension = os.path.splitext(file_path)
    return extension.lower()

input_file_path = "lech205.pdf"

file_type = get_file_type_safely(input_file_path)

if file_type ==".docx":
    print("The given file is a docx file so no OCR required and text can be directly extracted.")
elif file_type ==".txt":
    print("The given file is a .txt file so no OCR required and text can be directly extracted.")
else:
    print("The given file is a .pdf file and may require OCR.")
# Out:
# The given file is a .pdf file and may require OCR.

# %%
#Extraction of text from the file depending on the file type. Not using ocr for docx and text files and checking with ocr_fallback_threshold for pdf file to know if ocr should
#be done or not. And if for a page ocr is needed then we are using ocr to extract the text from all the image elements of the page and using normal get_text function of 
#pyMupdf(fitz) to extract the rest of the digitally recognizable text
import langchain
from langchain_community.document_loaders import TextLoader, UnstructuredWordDocumentLoader
import fitz
from PIL import Image
import io
import pytesseract
from langchain.docstore.document import Document 

if file_type ==".txt":
    loader = TextLoader(input_file_path)
    documents = loader.load()
elif file_type ==".docx" or file_type==".doc":
    loader = UnstructuredWordDocumentLoader(input_file_path)
    documents = loader.load()
else:
    ##Document is in pdf format and may require OCR
    document = fitz.open(input_file_path)
    all_pages_text = []

    for page_num in range(len(document)):
        page = document.load_page(page_num)
        page_text = page.get_text()
        
        # 2. Get all images on the page
        image_list = page.get_images(full=True)
        
        # 3. If images are found, perform OCR on them
        if image_list:
            print(f"Page No.{page_num + 1}: Found {len(image_list)} image(s). Performing targeted OCR.")
            for img_index, img in enumerate(image_list):
                xref = img[0]
                base_image = document.extract_image(xref)
                image_bytes = base_image["image"]
            
                image = Image.open(io.BytesIO(image_bytes))
                ocr_text = pytesseract.image_to_string(image)
        
                page_text += "\n" + ocr_text
        else:
             print(f"Page No.{page_num + 1}: No images found. Direct extraction only.")

        all_pages_text.append(page_text)
        
    document.close()
    full_pdf_text = "\n\n".join(all_pages_text)
    documents = [Document(page_content=full_pdf_text, metadata={"source": input_file_path})] 

content = documents[0].page_content
word_list = content.split()
word_count = len(word_list)
print(word_count)
# Out:
# Page No.1: Found 3 image(s). Performing targeted OCR.
# Page No.2: Found 18 image(s). Performing targeted OCR.
# Page No.3: Found 2 image(s). Performing targeted OCR.
# Page No.4: Found 2 image(s). Performing targeted OCR.
# Page No.5: Found 2 image(s). Performing targeted OCR.
# Page No.6: Found 2 image(s). Performing targeted OCR.
# Page No.7: Found 2 image(s). Performing targeted OCR.
# Page No.8: Found 2 image(s). Performing targeted OCR.
# Page No.9: Found 2 image(s). Performing targeted OCR.
# Page No.10: Found 60 image(s). Performing targeted OCR.
# Page No.11: Found 42 image(s). Performing targeted OCR.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 39
#      36         image_bytes = base_image["image"]
#      38         image = Image.open(io.BytesIO(image_bytes))
# ---> 39         ocr_text = pytesseract.image_to_string(image)
#      41         page_text += "\n" + ocr_text
#      42 else:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pytesseract/pytesseract.py:486, in image_to_string(image, lang, config, nice, output_type, timeout)
#     481 """
#     482 Returns the result of a Tesseract OCR run on the provided image to string
#     483 """
#     484 args = [image, 'txt', lang, config, nice, timeout]
# --> 486 return {
#     487     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     488     Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     489     Output.STRING: lambda: run_and_get_output(*args),
#     490 }[output_type]()
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pytesseract/pytesseract.py:489, in image_to_string.<locals>.<lambda>()
#     481 """
#     482 Returns the result of a Tesseract OCR run on the provided image to string
#     483 """
#     484 args = [image, 'txt', lang, config, nice, timeout]
#     486 return {
#     487     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     488     Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 489     Output.STRING: lambda: run_and_get_output(*args),
#     490 }[output_type]()
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pytesseract/pytesseract.py:352, in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     341 with save(image) as (temp_name, input_filename):
#     342     kwargs = {
#     343         'input_filename': input_filename,
#     344         'output_filename_base': temp_name,
#    (...)
#     349         'timeout': timeout,
#     350     }
# --> 352     run_tesseract(**kwargs)
#     353     return _read_output(
#     354         f"{kwargs['output_filename_base']}{extsep}{extension}",
#     355         return_bytes,
#     356     )
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pytesseract/pytesseract.py:282, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     279     else:
#     280         raise TesseractNotFoundError()
# --> 282 with timeout_manager(proc, timeout) as error_string:
#     283     if proc.returncode:
#     284         raise TesseractError(proc.returncode, get_errors(error_string))
#
# File /opt/homebrew/anaconda3/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pytesseract/pytesseract.py:144, in timeout_manager(proc, seconds)
#     142 try:
#     143     if not seconds:
# --> 144         yield proc.communicate()[1]
#     145         return
#     147     try:
#
# File /opt/homebrew/anaconda3/lib/python3.11/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File /opt/homebrew/anaconda3/lib/python3.11/subprocess.py:2108, in Popen._communicate(self, input, endtime, orig_timeout)
#    2101     self._check_timeout(endtime, orig_timeout,
#    2102                         stdout, stderr,
#    2103                         skip_check_and_raise=True)
#    2104     raise RuntimeError(  # Impossible :)
#    2105         '_check_timeout(..., skip_check_and_raise=True) '
#    2106         'failed to raise TimeoutExpired.')
# -> 2108 ready = selector.select(timeout)
#    2109 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2111 # XXX Rewrite these to use non-blocking I/O on the file
#    2112 # objects; they are no longer using C stdio!
#
# File /opt/homebrew/anaconda3/lib/python3.11/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
##Chunking of the pdf using RecursuveCharacterTextSplitter of langchain while keeping overlap between the chunks to prevent it from breaking sentences or paragraphs
#in half, which would destroy their meaning. Then we have made parallel llm api calls to summarize each chunk and then combined all their summaries. Then we gave the 
#combined summary to the llm in order to generate questions that can be answered on basis of the document and will be suitable for using as query to RAG to retrieve chunks 
#which are relevant for metadata generation. We used those questions as query for RAG to retrieve the relevant chunks. Then we gave the retrieved chunks along with the 
#combined summary to the llm for metadata extraction. We have used gemini 2.0 flash as llm model and 
from langchain_text_splitters import RecursiveCharacterTextSplitter, CharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
import google.generativeai as genai
import os
from langchain_community.vectorstores import Chroma
import dotenv
from dotenv import load_dotenv
import asyncio
import shutil
import chromadb
from langchain_community.embeddings import HuggingFaceEmbeddings 



load_dotenv()

google_api_key = os.getenv("GOOGLE_API_KEY")

genai.configure(api_key=google_api_key)

llm_model = genai.GenerativeModel("gemini-2.0-flash")


text_splitter = RecursiveCharacterTextSplitter(chunk_size = 1250, chunk_overlap=250)
docs = text_splitter.split_documents(documents)

embedding_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")


db = Chroma.from_documents(docs, embedding_model)

retriever = db.as_retriever(search_type="similarity", search_kwargs={"k": 3})

async def summarize_chunk_with_sdk(model, chunk_text, chunk_number, semaphore):
    async with semaphore:
        print(f"  -> Starting API call for chunk {chunk_number}...")
        
        prompt = f"Provide a very concise 1-2 sentence summary of the following text excerpt:\n\n---{chunk_text}\n---. Any data in the excerpt which is relevant for metadata generation like file name, author name, title etc should be included in the summary as the summary will be later used for metadata generation. Also give the word count of the chunk after the summary."
        response = await model.generate_content_async(prompt)
        print(f"  <- Success on chunk {chunk_number}.")
        return response.text.strip()

llm_model_async = genai.GenerativeModel("gemini-2.0-flash")
concurrency_limit = 50
semaphore = asyncio.Semaphore(concurrency_limit)

tasks = []
for i, chunk in enumerate(docs):
    task = summarize_chunk_with_sdk(llm_model_async, chunk.page_content, i + 1, semaphore)
    
    tasks.append(task)
    
# 4. Gather the results concurrently
summaries = await asyncio.gather(*tasks)

combined_summaries = "\n".join(summaries)

# print("\n--- COMBINED SUMMARIES (Using Async SDK) ---")
# print(combined_summaries)

prompt = "You have been given a sequence of summaries combined which are basically the summaries of chunks of a large pdf. You have to give me three questions that can be answered by the pdf. These questions when used in RAG should be able to retrieve chunks of the pdf which are relevant for semantically rich metadata generation. The combined sequence of summaries is: {combined_summaries}. As an output only give the questions."

response = llm_model.generate_content(prompt)
# print("------------------------------------------------------------------------------------")
# print(response.text)
query_for_retriever = response.text

relevant_docs = retriever.invoke(query_for_retriever)

retrieved_context_list = [doc.page_content for doc in relevant_docs]


retrieved_context = "\n".join(retrieved_context_list)

final_prompt = f"""
You are an expert document analyst and metadata generation specialist. Your task is to synthesize information from two distinct sources: a high-level summary of a document and specific, relevant excerpts from the original text.

Based on ALL the information provided below, generate a single, clean JSON object containing the document's metadata. The metadata should also have summary of the document. Also you've been given that the word count of the document is: {word_count}. Mention this word count as it is in the metadata.

**IMPORTANT RULES:**
1.  Your entire response MUST be only the JSON object, with no introductory text, explanations, or any characters before or after the opening and closing curly braces (`{{` and `}}`).
2.  The JSON object must strictly adhere to the specified structure and keys.

---
**INPUT SOURCE 1: OVERALL DOCUMENT SUMMARY**
(This provides the high-level context and gist of the entire document. This is basically a sequence of summaries of all the chunks of the document. Each sdummary also contains the word count of each chunk. In the metadata you are finally giving, also give the total word count.)

{combined_summaries}
---
**INPUT SOURCE 2: RELEVANT EXCERPTS FROM ORIGINAL TEXT**
(This provides specific, detailed evidence and facts.)

{retrieved_context}
---"""

metadata_response = llm_model.generate_content(final_prompt)

metadata = metadata_response.text

print(metadata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 30
#      26 llm_model = genai.GenerativeModel("gemini-2.0-flash")
#      29 text_splitter = RecursiveCharacterTextSplitter(chunk_size = 1250, chunk_overlap=250)
# ---> 30 docs = text_splitter.split_documents(documents)
#      32 embedding_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
#      35 db = Chroma.from_documents(docs, embedding_model)
#
# NameError: name 'documents' is not defined

# %%
##Here I have combined all the previous steps in a single cell block of code
import langchain
from langchain_community.document_loaders import TextLoader, UnstructuredWordDocumentLoader
import fitz
from PIL import Image
import io
import pytesseract
from langchain.docstore.document import Document 
import os
import dotenv
from dotenv import load_dotenv
import asyncio
import shutil
import chromadb
from langchain_community.vectorstores import Chroma
from langchain_text_splitters import RecursiveCharacterTextSplitter, CharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
import google.generativeai as genai
from langchain_community.embeddings import HuggingFaceEmbeddings 



load_dotenv()

openai_api_key = os.getenv("OPENAI_API_KEY")
google_api_key = os.getenv("GOOGLE_API_KEY")

genai.configure(api_key=google_api_key)

def get_file_type_safely(file_path):
    _ , extension = os.path.splitext(file_path)
    return extension.lower()

input_file_path = "combined.pdf"

file_type = get_file_type_safely(input_file_path)

if file_type ==".docx":
    print("The given file is a docx file so no OCR required and text can be directly extracted.")
elif file_type ==".txt":
    print("The given file is a .txt file so no OCR required and text can be directly extracted.")
else:
    print("The given file is a .pdf file and may require OCR.")

if file_type ==".txt":
    loader = TextLoader(input_file_path)
    documents = loader.load()
elif file_type ==".docx" or file_type==".doc":
    loader = UnstructuredWordDocumentLoader(input_file_path)
    documents = loader.load()
else:
    ##Document is in pdf format and may require OCR
    document = fitz.open(input_file_path)
    all_pages_text = []

    for page_num in range(len(document)):
        page = document.load_page(page_num)
        page_text = page.get_text()
        
        # 2. Get all images on the page
        image_list = page.get_images(full=True)
        
        # 3. If images are found, perform OCR on them
        if image_list:
            print(f"Page No.{page_num + 1}: Found {len(image_list)} image(s). Performing targeted OCR.")
            for img_index, img in enumerate(image_list):
                xref = img[0]
                base_image = document.extract_image(xref)
                image_bytes = base_image["image"]
            
                image = Image.open(io.BytesIO(image_bytes))
                ocr_text = pytesseract.image_to_string(image)
        
                page_text += "\n" + ocr_text
        else:
             print(f"Page No.{page_num + 1}: No images found. Direct extraction only.")

        all_pages_text.append(page_text)
        
    document.close()
    full_pdf_text = "\n\n".join(all_pages_text)
    documents = [Document(page_content=full_pdf_text, metadata={"source": input_file_path})]

content = documents[0].page_content
word_list = content.split()
word_count = len(word_list)

llm_model = genai.GenerativeModel("gemini-2.0-flash")

text_splitter = RecursiveCharacterTextSplitter(chunk_size = 1250, chunk_overlap=250)
docs = text_splitter.split_documents(documents)

embedding_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

db = Chroma.from_documents(docs, embedding_model)

retriever = db.as_retriever(search_type="similarity", search_kwargs={"k": 3})

async def summarize_chunk_with_sdk(model, chunk_text, chunk_number, semaphore):
    async with semaphore:
        print(f"  -> Starting API call for chunk {chunk_number}...")
        
        prompt = f"Provide a very concise 1-2 sentence summary of the following text excerpt:\n\n---{chunk_text}\n---. Any data in the excerpt which is relevant for metadata generation like file name, author name, title etc should be included in the summary as the summary will be later used for metadata generation. Also give the word count of the chunk after the summary."
        # print(prompt)
        response = await model.generate_content_async(prompt)
        print(f"  <- Success on chunk {chunk_number}.")
        return response.text.strip()

llm_model_async = genai.GenerativeModel("gemini-2.0-flash")
concurrency_limit = 50
semaphore = asyncio.Semaphore(concurrency_limit)

tasks = []
for i, chunk in enumerate(docs):
    task = summarize_chunk_with_sdk(llm_model_async, chunk.page_content, i + 1, semaphore)
    
    tasks.append(task)
    
summaries = await asyncio.gather(*tasks)

combined_summaries = "\n".join(summaries)

prompt = "You have been given a sequence of summaries combined which are basically the summaries of chunks of a large pdf. You have to give me three questions that can be answered by the pdf. These questions when used in RAG should be able to retrieve chunks of the pdf which are relevant for semantically rich metadata generation. The combined sequence of summaries is: {combined_summaries}. As an output only give the questions."

response = llm_model.generate_content(prompt)
query_for_retriever = response.text

relevant_docs = retriever.invoke(query_for_retriever)

retrieved_context_list = [doc.page_content for doc in relevant_docs]


retrieved_context = "\n".join(retrieved_context_list)

final_prompt = f"""
You are an expert document analyst and metadata generation specialist. Your task is to synthesize information from two distinct sources: a high-level summary of a document and specific, relevant excerpts from the original text.

Based on ALL the information provided below, generate a single, clean JSON object containing the document's metadata. The metadata should also have summary of the document. Also you've been given that the word count of the document is: {word_count}. Mention this word count as it is in the metadata.

**IMPORTANT RULES:**
1.  Your entire response MUST be only the JSON object, with no introductory text, explanations, or any characters before or after the opening and closing curly braces (`{{` and `}}`).
2.  The JSON object must strictly adhere to the specified structure and keys.

---
**INPUT SOURCE 1: OVERALL DOCUMENT SUMMARY**
(This provides the high-level context and gist of the entire document. This is basically a sequence of summaries of all the chunks of the document. Each sdummary also contains the word count of each chunk. In the metadata you are finally giving, also give the total word count.)

{combined_summaries}
---
**INPUT SOURCE 2: RELEVANT EXCERPTS FROM ORIGINAL TEXT**
(This provides specific, detailed evidence and facts.)

{retrieved_context}
---"""

metadata_response = llm_model.generate_content(final_prompt)

metadata = metadata_response.text

print(metadata)
# Out:
# The given file is a .pdf file and may require OCR.
# Page No.1: Found 4 image(s). Performing targeted OCR.
# Page No.2: Found 2 image(s). Performing targeted OCR.
# Page No.3: Found 21 image(s). Performing targeted OCR.
# Page No.4: Found 19 image(s). Performing targeted OCR.
# Page No.5: Found 20 image(s). Performing targeted OCR.
# Page No.6: Found 20 image(s). Performing targeted OCR.
# Page No.7: Found 30 image(s). Performing targeted OCR.
# Page No.8: Found 14 image(s). Performing targeted OCR.
# Page No.9: Found 20 image(s). Performing targeted OCR.
# Page No.10: Found 2 image(s). Performing targeted OCR.
# Page No.11: Found 2 image(s). Performing targeted OCR.
# Page No.12: Found 14 image(s). Performing targeted OCR.
# Page No.13: Found 2 image(s). Performing targeted OCR.
# Page No.14: Found 2 image(s). Performing targeted OCR.
# Page No.15: Found 2 image(s). Performing targeted OCR.
# Page No.16: Found 22 image(s). Performing targeted OCR.
# Page No.17: Found 2 image(s). Performing targeted OCR.
# Page No.18: Found 2 image(s). Performing targeted OCR.
# Page No.19: Found 45 image(s). Performing targeted OCR.
# Page No.20: Found 20 image(s). Performing targeted OCR.
# Page No.21: Found 3 image(s). Performing targeted OCR.
# Page No.22: Found 3 image(s). Performing targeted OCR.
# Page No.23: Found 4 image(s). Performing targeted OCR.
# Page No.24: Found 2 image(s). Performing targeted OCR.
# Page No.25: Found 2 image(s). Performing targeted OCR.
# Page No.26: Found 22 image(s). Performing targeted OCR.
# Page No.27: Found 16 image(s). Performing targeted OCR.
# Page No.28: Found 2 image(s). Performing targeted OCR.
# Page No.29: Found 2 image(s). Performing targeted OCR.
# Page No.30: Found 36 image(s). Performing targeted OCR.
# Page No.31: Found 27 image(s). Performing targeted OCR.
# Page No.32: Found 25 image(s). Performing targeted OCR.
# Page No.33: Found 2 image(s). Performing targeted OCR.
# Page No.34: Found 28 image(s). Performing targeted OCR.
# Page No.35: Found 2 image(s). Performing targeted OCR.
# Page No.36: Found 41 image(s). Performing targeted OCR.
# Page No.37: Found 41 image(s). Performing targeted OCR.
# Page No.38: Found 2 image(s). Performing targeted OCR.
# Page No.39: Found 34 image(s). Performing targeted OCR.
# Page No.40: Found 34 image(s). Performing targeted OCR.
# Page No.41: Found 47 image(s). Performing targeted OCR.
# Page No.42: Found 2 image(s). Performing targeted OCR.
# Page No.43: Found 33 image(s). Performing targeted OCR.
# Page No.44: Found 45 image(s). Performing targeted OCR.
# Page No.45: Found 2 image(s). Performing targeted OCR.
# Page No.46: Found 2 image(s). Performing targeted OCR.
# Page No.47: Found 2 image(s). Performing targeted OCR.
# Page No.48: Found 26 image(s). Performing targeted OCR.
# Page No.49: Found 2 image(s). Performing targeted OCR.
# Page No.50: Found 54 image(s). Performing targeted OCR.
# Page No.51: Found 40 image(s). Performing targeted OCR.
# Page No.52: Found 2 image(s). Performing targeted OCR.
# Page No.53: Found 3 image(s). Performing targeted OCR.
# Page No.54: Found 2 image(s). Performing targeted OCR.
# /var/folders/yn/7wm3zbp54gxbjlhxp3g95rg80000gn/T/ipykernel_49480/3509055515.py:92: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
#   -> Starting API call for chunk 1...
#   -> Starting API call for chunk 2...
#   -> Starting API call for chunk 3...
#   -> Starting API call for chunk 4...
#   -> Starting API call for chunk 5...
#   -> Starting API call for chunk 6...
#   -> Starting API call for chunk 7...
#   -> Starting API call for chunk 8...
#   -> Starting API call for chunk 9...
#   -> Starting API call for chunk 10...
#   -> Starting API call for chunk 11...
#   -> Starting API call for chunk 12...
#   -> Starting API call for chunk 13...
#   -> Starting API call for chunk 14...
#   -> Starting API call for chunk 15...
#   -> Starting API call for chunk 16...
#   -> Starting API call for chunk 17...
#   -> Starting API call for chunk 18...
#   -> Starting API call for chunk 19...
#   -> Starting API call for chunk 20...
#   -> Starting API call for chunk 21...
#   -> Starting API call for chunk 22...
#   -> Starting API call for chunk 23...
#   -> Starting API call for chunk 24...
#   -> Starting API call for chunk 25...
#   -> Starting API call for chunk 26...
#   -> Starting API call for chunk 27...
#   -> Starting API call for chunk 28...
#   -> Starting API call for chunk 29...
#   -> Starting API call for chunk 30...
#   -> Starting API call for chunk 31...
#   -> Starting API call for chunk 32...
#   -> Starting API call for chunk 33...
#   -> Starting API call for chunk 34...
#   -> Starting API call for chunk 35...
#   -> Starting API call for chunk 36...
#   -> Starting API call for chunk 37...
#   -> Starting API call for chunk 38...
#   -> Starting API call for chunk 39...
#   -> Starting API call for chunk 40...
#   -> Starting API call for chunk 41...
#   -> Starting API call for chunk 42...
#   -> Starting API call for chunk 43...
#   -> Starting API call for chunk 44...
#   -> Starting API call for chunk 45...
#   -> Starting API call for chunk 46...
#   -> Starting API call for chunk 47...
#   -> Starting API call for chunk 48...
#   -> Starting API call for chunk 49...
#   -> Starting API call for chunk 50...
#   <- Success on chunk 18.
#   -> Starting API call for chunk 51...
#   <- Success on chunk 38.
#   <- Success on chunk 45.
#   -> Starting API call for chunk 52...
#   -> Starting API call for chunk 53...
#   <- Success on chunk 4.
#   <- Success on chunk 48.
#   <- Success on chunk 1.
#   -> Starting API call for chunk 54...
#   -> Starting API call for chunk 55...
#   -> Starting API call for chunk 56...
#   <- Success on chunk 36.
#   -> Starting API call for chunk 57...
#   <- Success on chunk 17.
#   <- Success on chunk 16.
#   <- Success on chunk 26.
#   <- Success on chunk 42.
#   <- Success on chunk 11.
#   <- Success on chunk 7.
#   -> Starting API call for chunk 58...
#   -> Starting API call for chunk 59...
#   -> Starting API call for chunk 60...
#   -> Starting API call for chunk 61...
#   -> Starting API call for chunk 62...
#   -> Starting API call for chunk 63...
#   <- Success on chunk 15.
#   <- Success on chunk 31.
#   <- Success on chunk 37.
#   <- Success on chunk 29.
#   <- Success on chunk 28.
#   <- Success on chunk 10.
#   <- Success on chunk 22.
#   <- Success on chunk 30.
#   -> Starting API call for chunk 64...
#   -> Starting API call for chunk 65...
#   -> Starting API call for chunk 66...
#   -> Starting API call for chunk 67...
#   -> Starting API call for chunk 68...
#   -> Starting API call for chunk 69...
#   -> Starting API call for chunk 70...
#   -> Starting API call for chunk 71...
#   <- Success on chunk 25.
#   <- Success on chunk 50.
#   <- Success on chunk 34.
#   <- Success on chunk 13.
#   <- Success on chunk 27.
#   <- Success on chunk 39.
#   <- Success on chunk 40.
#   <- Success on chunk 3.
#   <- Success on chunk 23.
#   <- Success on chunk 46.
#   <- Success on chunk 43.
#   <- Success on chunk 32.
#   <- Success on chunk 14.
#   <- Success on chunk 33.
#   -> Starting API call for chunk 72...
#   -> Starting API call for chunk 73...
#   -> Starting API call for chunk 74...
#   -> Starting API call for chunk 75...
#   -> Starting API call for chunk 76...
#   -> Starting API call for chunk 77...
#   -> Starting API call for chunk 78...
#   -> Starting API call for chunk 79...
#   -> Starting API call for chunk 80...
#   -> Starting API call for chunk 81...
#   -> Starting API call for chunk 82...
#   -> Starting API call for chunk 83...
#   -> Starting API call for chunk 84...
#   -> Starting API call for chunk 85...
#   <- Success on chunk 12.
#   -> Starting API call for chunk 86...
#   <- Success on chunk 5.
#   <- Success on chunk 44.
#   <- Success on chunk 49.
#   -> Starting API call for chunk 87...
#   -> Starting API call for chunk 88...
#   -> Starting API call for chunk 89...
#   <- Success on chunk 24.
#   -> Starting API call for chunk 90...
#   <- Success on chunk 19.
#   -> Starting API call for chunk 91...
#   <- Success on chunk 8.
#   <- Success on chunk 6.
#   <- Success on chunk 52.
#   -> Starting API call for chunk 92...
#   -> Starting API call for chunk 93...
#   -> Starting API call for chunk 94...
#   <- Success on chunk 2.
#   <- Success on chunk 51.
#   <- Success on chunk 9.
#   <- Success on chunk 41.
#   -> Starting API call for chunk 95...
#   -> Starting API call for chunk 96...
#   -> Starting API call for chunk 97...
#   -> Starting API call for chunk 98...
#   <- Success on chunk 35.
#   -> Starting API call for chunk 99...
#   <- Success on chunk 53.
#   <- Success on chunk 21.
#   <- Success on chunk 20.
#   -> Starting API call for chunk 100...
#   -> Starting API call for chunk 101...
#   -> Starting API call for chunk 102...
#   <- Success on chunk 47.
#   -> Starting API call for chunk 103...
#   <- Success on chunk 54.
#   -> Starting API call for chunk 104...
#   <- Success on chunk 55.
#   -> Starting API call for chunk 105...
#   <- Success on chunk 57.
#   <- Success on chunk 56.
#   <- Success on chunk 61.
#   <- Success on chunk 58.
#   <- Success on chunk 60.
#   <- Success on chunk 63.
#   <- Success on chunk 59.
#   <- Success on chunk 62.
#   <- Success on chunk 65.
#   <- Success on chunk 64.
#   <- Success on chunk 71.
#   <- Success on chunk 70.
#   <- Success on chunk 67.
#   <- Success on chunk 77.
#   <- Success on chunk 74.
#   <- Success on chunk 78.
#   <- Success on chunk 72.
#   <- Success on chunk 76.
#   <- Success on chunk 75.
#   <- Success on chunk 99.
#   <- Success on chunk 73.
#   <- Success on chunk 79.
#   <- Success on chunk 66.
#   <- Success on chunk 68.
#   <- Success on chunk 90.
#   <- Success on chunk 69.
#   <- Success on chunk 80.
#   <- Success on chunk 98.
#   <- Success on chunk 81.
#   <- Success on chunk 102.
#   <- Success on chunk 103.
#   <- Success on chunk 100.
#   <- Success on chunk 84.
#   <- Success on chunk 86.
#   <- Success on chunk 85.
#   <- Success on chunk 97.
#   <- Success on chunk 91.
#   <- Success on chunk 95.
#   <- Success on chunk 96.
#   <- Success on chunk 89.
#   <- Success on chunk 82.
#   <- Success on chunk 94.
#   <- Success on chunk 93.
#   <- Success on chunk 92.
#   <- Success on chunk 87.
#   <- Success on chunk 83.
#   <- Success on chunk 104.
#   <- Success on chunk 88.
#   <- Success on chunk 101.
#   <- Success on chunk 105.
# ```json
# {
#   "title": "Amines, Aldehydes, Ketones, and Carboxylic Acids",
#   "description": "This document covers amines, aldehydes, ketones, and carboxylic acids, including their nomenclature, structure, preparation, reactions, properties, and uses in organic chemistry. It details the classification, naming conventions (IUPAC and common), physical properties (boiling point, solubility), and chemical reactions (oxidation, reduction, nucleophilic addition, electrophilic substitution) of these compounds. The document also includes methods of preparation, distinguishing tests, and examples, exercises, and intext questions to help the reader understand the concepts. The document also presents common organic chemistry problems, including compound identification, synthesis, and conversions involving named reactions. Aromatic and aliphatic amines are compared, and the industrial importance of various carbonyl compounds is highlighted.",
#   "keywords": [
#     "amines",
#     "diazonium salts",
#     "aldehydes",
#     "ketones",
#     "carboxylic acids",
#     "nomenclature",
#     "IUPAC",
#     "common names",
#     "structure",
#     "preparation",
#     "reactions",
#     "properties",
#     "oxidation",
#     "reduction",
#     "nucleophilic addition",
#     "electrophilic substitution",
#     "basicity",
#     "acidity",
#     "hydrogen bonding",
#     "azo dyes",
#     "Gabriel phthalimide synthesis",
#     "Hoffmann bromamide degradation",
#     "Sandmeyer reaction",
#     "Gattermann reaction",
#     "Tollens' test",
#     "Fehling's test",
#     "Aldol condensation",
#     "Cannizzaro reaction",
#     "esterification",
#     "Grignard reagents",
#     "ozonolysis",
#     "haloform reaction",
#     "Hinsberg's reagent",
#     "aromatic compounds",
#     "aliphatic compounds",
#     "organic chemistry",
#     "chemical synthesis",
#     "reprint 2024-25"
#   ],
#   "word_count": 13872,
#   "summary": "This document provides a comprehensive overview of amines, aldehydes, ketones, and carboxylic acids. It begins by introducing amines as ammonia derivatives and discussing their classification, nomenclature, preparation, properties, and uses. The text then delves into aldehydes, ketones, and carboxylic acids, covering their nomenclature, structure, preparation, reactions, properties, and uses. Key topics include oxidation and reduction reactions, nucleophilic addition reactions, and electrophilic substitution reactions. The document highlights the importance of these compounds in various applications, including pharmaceuticals, dyes, solvents, and the chemical industry. It also contains in-text questions, example problems, and solutions to aid in understanding and application of the concepts. Aromatic and aliphatic amines are compared and contrasted. Additionally, topics such as the Gabriel phthalimide synthesis, Hoffmann bromamide degradation, Sandmeyer reaction, Gattermann reaction, Tollens’ test, Fehling's test, Aldol condensation, Cannizzaro reaction, and esterification are explained. The role of Grignard reagents and ozonolysis in preparing aldehydes and ketones are also discussed. The document also contains practice problems involving synthesis completion, explanation of chemical phenomena and identification of unknown organic compound based on its reactions and composition.",
#   "metadata": {
#     "type": "textbook chapter",
#     "subject": "chemistry",
#     "level": "class XII",
#     "reprint_date": "2024-25",
#     "units_covered": [
#       "Unit 8",
#       "Unit 9"
#     ]
#   },
#   "relevant_excerpts": [
#     "is explained on the basis of resonance involving a neutral (A) and a dipolar (B) structures as shown.",
#     "Some important methods for the preparation of aldehydes and ketones are as follows:\n1. By oxidation of alcohols\nAldehydes and ketones are generally prepared by oxidation of primary and secondary alcohols, respectively (Unit 7, Class XII).\n2. By dehydrogenation of alcohols\nThis method is suitable for volatile alcohols and is of industrial application. In this method alcohol vapours are passed over heavy metal catalysts (Ag or Cu). Primary and secondary alcohols give aldehydes and ketones, respectively (Unit 7, Class XII).\n3. From hydrocarbons\n(i) By ozonolysis of alkenes: As we know, ozonolysis of alkenes followed by reaction with zinc dust and water gives aldehydes,",
#     "(i) C6H5NH2 < NH3 < C6H5CH2NH2 < C2H5NH2 < (C2H5)2NH",
#     "(ii) C6H5NH2 < C2H5NH2. < (C2H5)3N < (C2H5)2NH",
#     "(iii) C6H5NH2 < C6H5CH2NH2 < (CH3)3N < CH3NH2 < (CH3)2NH"
#   ]
# }
# ```

# %%
##Here I have integrated the full code of metadata genaration (present in orevious cell) into a gradio interface. Run this code for generating link for the interface. 
#Please don't click on the link already there. Run the code to generate a new link.
import gradio as gr
import langchain
from langchain_community.document_loaders import TextLoader, UnstructuredWordDocumentLoader
import fitz  
from PIL import Image
import io
import pytesseract
from langchain.docstore.document import Document 
import os
import dotenv
from dotenv import load_dotenv
import asyncio
import shutil
import chromadb
from langchain_community.vectorstores import Chroma
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
import google.generativeai as genai
import time
import json
from langchain_community.embeddings import HuggingFaceEmbeddings 


load_dotenv()

google_api_key = os.getenv("GOOGLE_API_KEY")
genai.configure(api_key=google_api_key)

async def generate_metadata_from_file(input_file_path):
    if not input_file_path:
        return "Please upload a file first."

    print(f"--- Starting Metadata Generation for: {os.path.basename(input_file_path)} ---")
    
    try:
        _ , extension = os.path.splitext(input_file_path)
        file_type = extension.lower()

        if file_type == ".txt":
            loader = TextLoader(input_file_path)
            documents = loader.load()
        elif file_type in [".docx", ".doc"]:
            loader = UnstructuredWordDocumentLoader(input_file_path)
            documents = loader.load()
        elif file_type == ".pdf":
            pdf_document = fitz.open(input_file_path)
            all_pages_text = []
            print(f"  -> PDF has {len(pdf_document)} pages. Starting extraction...")
            
            for page_num in range(len(pdf_document)):
                page = pdf_document.load_page(page_num)
                page_text = page.get_text()
                
                image_list = page.get_images(full=True)
                ocr_fallback_threshold = 200
                if image_list and len(page_text) < ocr_fallback_threshold:
                    print(f"    - Page {page_num + 1}: Found {len(image_list)} image(s). Performing OCR.")
                    for img_index, img in enumerate(image_list):
                        xref = img[0]
                        try:
                            base_image = pdf_document.extract_image(xref)
                            image_bytes = base_image["image"]
                            image = Image.open(io.BytesIO(image_bytes))
                            ocr_text = pytesseract.image_to_string(image)
                            page_text += "\n" + ocr_text
                        except Exception as e:
                            print(f"      - Warning: Could not process image {img_index+1} on page {page_num+1}. Error: {e}")
                else:
                     print(f"    - Page {page_num + 1}: No images found. Direct text extraction only.")

                all_pages_text.append(page_text)
                
            pdf_document.close()
            full_pdf_text = "\n\n".join(all_pages_text)
            print(full_pdf_text)
            documents = [Document(page_content=full_pdf_text, metadata={"source": os.path.basename(input_file_path)})]
        else:
            return f"Unsupported file type: {file_type}. Please upload a .pdf, .docx, or .txt file."
        content = documents[0].page_content
        word_list = content.split()
        word_count = len(word_list)
        
        print("  -> Document loaded successfully.")

    except Exception as e:
        return f"Error during file loading: {e}"

    # 2. Split documents into chunks
    print("[2/7] Splitting text into chunks...")
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1250, chunk_overlap=250)
    docs = text_splitter.split_documents(documents)
    print(f"  -> Document split into {len(docs)} chunks.")

    # 3. Create embeddings and vector store
    print("[3/7] Creating embeddings and vector store...")
    embedding_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
    db = Chroma.from_documents(docs, embedding_model)
    retriever = db.as_retriever(search_type="similarity", search_kwargs={"k": 3})
    print("  -> Vector store created.")

    # 4. Asynchronously summarize chunks
    print(f"[4/7] Summarizing {len(docs)} chunks concurrently (limit: 200)...")
    llm_model_async = genai.GenerativeModel("gemini-1.5-flash") # Updated model
    concurrency_limit = 200
    semaphore = asyncio.Semaphore(concurrency_limit)

    async def summarize_chunk_with_sdk(model, chunk_text, chunk_number, semaphore):
        async with semaphore:
            prompt = f"Provide a very concise 1-2 sentence summary of the following text excerpt:\n\n---{chunk_text}\n---. Any data in the excerpt which is relevant for metadata generation like file name, author name, title etc should be included in the summary as the summary will be later used for metadata generation. Also give the word count of the chunk after the summary. The wrod count should be given after the summary as: Word Count="
            try:
                response = await model.generate_content_async(prompt)
                return response.text.strip()
            except Exception as e:
                print(f"  -> Error summarizing chunk {chunk_number}: {e}")
                return f"Error summarizing chunk {chunk_number}."

    tasks = [summarize_chunk_with_sdk(llm_model_async, chunk.page_content, i + 1, semaphore) for i, chunk in enumerate(docs)]
    summaries = await asyncio.gather(*tasks)
    combined_summaries = "\n".join(summaries)
    print("  -> All chunks summarized.")

    # 5. Generate questions for retrieval
    print("[5/7] Generating retriever questions...")
    llm_model = genai.GenerativeModel("gemini-1.5-flash") # Updated model
    prompt_for_questions = f"You have been given a sequence of summaries combined which are basically the summaries of chunks of a large document. You have to give me three questions that can be answered by the document. These questions when used in RAG should be able to retrieve chunks of the pdf which are relevant for semantically rich metadata generation. The combined sequence of summaries is: {combined_summaries}. As an output only give the questions."
    question_response = llm_model.generate_content(prompt_for_questions)
    query_for_retriever = question_response.text
    print(f"  -> Generated questions:\n{query_for_retriever}")
    
    # 6. Retrieve relevant context
    print("[6/7] Retrieving relevant context...")
    relevant_docs = retriever.invoke(query_for_retriever)
    retrieved_context = "\n".join([doc.page_content for doc in relevant_docs])
    print("  -> Context retrieved.")

    # 7. Generate final metadata JSON
    print("[7/7] Generating final metadata JSON...")
    final_prompt = f"""
    You are an expert document analyst and metadata generation specialist. Your task is to synthesize information from two distinct sources: a high-level summary of a document and specific, relevant excerpts from the original text.

    Based on ALL the information provided below, generate a single, clean JSON object containing the document's metadata. The metadata should also have a summary of the document. Also you've been given that the word count of the document is: {word_count}. Mention this word count as it is in the metadata.

    **IMPORTANT RULES:**
    1.  Your entire response MUST be only the JSON object, with no introductory text, explanations, or any characters before or after the opening and closing curly braces (`{{` and `}}`).
    2.  The JSON object must strictly adhere to the specified structure and keys.

    ---
    **INPUT SOURCE 1: OVERALL DOCUMENT SUMMARY**
    (This provides the high-level context and gist of the entire document. This is basically a sequence of summaries of all the chunks of the document. Each summary also contains the word count of each summary. These word counts are present as: Word Count= . Summ all these word counts ang vie that as the total wordcount of pdf in its metadata.)

    {combined_summaries}
    ---
    **INPUT SOURCE 2: RELEVANT EXCERPTS FROM ORIGINAL TEXT**
    (This provides specific, detailed evidence and facts.)

    {retrieved_context}
    ---"""

    metadata_response = llm_model.generate_content(final_prompt)
    metadata_text = metadata_response.text.strip()
    
    if metadata_text.startswith("```json"):
        metadata_text = metadata_text[7:]
    if metadata_text.endswith("```"):
        metadata_text = metadata_text[:-3]

    print("--- Metadata Generation Complete ---")
    
    return metadata_text



def create_gradio_interface():
    def sync_wrapper(file):
        if file is None:
            return "Please upload a file to begin.", None
        
        input_path = file.name
        
        result = asyncio.run(generate_metadata_from_file(input_path))
        
        try:
            json_result = json.loads(result)
            return json_result
        except (json.JSONDecodeError, TypeError):
            return {result}

    with gr.Blocks(theme=gr.themes.Soft(), title="Automated Metadata Extractor") as demo:
        gr.Markdown(
            """
            # 📄 Automated Metadata Extractor
            Upload a document (`.pdf`, `.docx`, `.txt`) to automatically extract and generate its metadata.
            The process involves text extraction, OCR for images in PDFs, chunking, summarization, and AI-powered metadata synthesis.
            """
        )
        
        with gr.Row():
            with gr.Column(scale=1):
                file_input = gr.File(label="Upload Document", file_types=[".pdf", ".docx", ".txt"])
                submit_button = gr.Button("Generate Metadata", variant="primary")
                
            with gr.Column(scale=2):
                json_output = gr.JSON(label="Extracted Metadata")
        
        submit_button.click(
            fn=sync_wrapper,
            inputs=file_input,
            outputs=json_output
        )
        
        gr.Examples(
            [["lech205.pdf"]],
            inputs=file_input,
        )

    return demo

if __name__ == "__main__":
    app = create_gradio_interface()
    app.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://93fdbc3966d7ce1cfb.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://93fdbc3966d7ce1cfb.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# --- Starting Metadata Generation for: lech204.pdf ---
#   -> PDF has 22 pages. Starting extraction...
#     - Page 1: No images found. Direct text extraction only.
#     - Page 2: No images found. Direct text extraction only.
#     - Page 3: No images found. Direct text extraction only.
#     - Page 4: No images found. Direct text extraction only.
#     - Page 5: No images found. Direct text extraction only.
#     - Page 6: No images found. Direct text extraction only.
#     - Page 7: No images found. Direct text extraction only.
#     - Page 8: No images found. Direct text extraction only.
#     - Page 9: No images found. Direct text extraction only.
#     - Page 10: No images found. Direct text extraction only.
#     - Page 11: No images found. Direct text extraction only.
#     - Page 12: No images found. Direct text extraction only.
#     - Page 13: No images found. Direct text extraction only.
#     - Page 14: No images found. Direct text extraction only.
#     - Page 15: No images found. Direct text extraction only.
#     - Page 16: No images found. Direct text extraction only.
#     - Page 17: No images found. Direct text extraction only.
#     - Page 18: No images found. Direct text extraction only.
#     - Page 19: No images found. Direct text extraction only.
#     - Page 20: No images found. Direct text extraction only.
#     - Page 21: No images found. Direct text extraction only.
#     - Page 22: No images found. Direct text extraction only.
# Amines constitute an important class of organic
# compounds derived by replacing one or more hydrogen
# atoms of ammonia molecule by alkyl/aryl group(s). In
# nature, they occur among proteins, vitamins, alkaloids
# and hormones. Synthetic examples include polymers,
# dye stuffs and drugs. Two biologically active
# compounds, namely adrenaline and ephedrine, both
# containing secondary amino group, are used to increase
# blood pressure. Novocain, a synthetic amino compound,
# is used as an anaesthetic in dentistry. Benadryl, a well
# known antihistaminic drug also contains tertiary amino
# group. Quaternary ammonium salts are used as
# surfactants. Diazonium salts are intermediates in the
# preparation of a  variety of aromatic compounds
# including dyes. In this Unit, you will learn about amines
# and diazonium salts.
# I. AMINES
# Amines can be considered as derivatives of ammonia,
# obtained by replacement of one, two or all the three
# hydrogen atoms by alkyl and/or aryl groups.
# For example:
# Like ammonia, nitrogen atom of amines is trivalent and
# carries an unshared pair of electrons.  Nitrogen orbitals
# in amines are therefore, sp3 hybridised and the geometry
# of amines is pyramidal. Each of  the three sp3 hybridised
# orbitals of nitrogen overlap with orbitals of hydrogen or
# carbon depending upon the composition of the amines.
# The fourth orbital of nitrogen in all amines contains an
# unshared pair of electrons.  Due to the presence of
# unshared pair of electrons, the angle C–N–E, (where E is
# After studying this Unit, you will be
# able to
# ·
# describe amines as derivatives of
# ammonia having a pyramidal
# structure;
# ·
# classify amines as primary,
# secondary and tertiary;
# ·
# name amines by common names
# and IUPAC system;
# ·
# describe some of the important
# methods of preparation of amines;
# ·
# explain the properties of amines;
# ·
# distinguish between primary,
# secondary and tertiary amines;
# ·
# describe the method of prepara-
# tion of diazonium salts and their
# importance in the synthesis of a
# series of aromatic compounds
# including azo dyes.
# Objectives
# “The chief commercial use of amines is as intermediates in the
# synthesis of medicines and fibres” .
# Unit
# Unit
# Unit
# Unit
# Unit9
# Amines
# mines
# mines
# mines
# mines9
# Amines
# mines
# mines
# mines
# mines
# 9.1 Structure of Amines
# 9.1 Structure of Amines
# 9.1 Structure of Amines
# 9.1 Structure of Amines
# 9.1 Structure of Amines
# Reprint 2024-25
#
#
# 260
# Chemistry
# C or H) is less than 109.5°; for instance, it is 108o in case of
# trimethylamine as shown in Fig. 9.1.
# Amines are classified as primary (1o), secondary (2o) and tertiary (3o)
# depending upon the number of hydrogen atoms replaced by alkyl or
# aryl groups in ammonia molecule.  If one hydrogen atom of ammonia
# is replaced by R or Ar , we get RNH2 or ArNH2, a primary amine (1o).
# If two hydrogen atoms of ammonia or one hydrogen atom of R-NH2 are
# replaced by another alkyl/aryl(R’) group,  what would you get? You
# get R-NHR’, secondary amine.  The second alkyl/aryl group may be
# same or different. Replacement of another hydrogen atom by alkyl/aryl
# group leads to the formation of tertiary amine. Amines are said to be
# ‘simple’ when all the alkyl or aryl groups are the same, and ‘mixed’
# when they are different.
# In common system, an aliphatic amine is named by prefixing alkyl
# group to amine, i.e., alkylamine as one word (e.g., methylamine).  In
# secondary and tertiary amines, when two or more groups are the same,
# the prefix di or tri is appended before the name of alkyl group.  In
# IUPAC system, primary amines are named as alkanamines. The name
# is derived by replacement of ‘e’ of alkane by the word amine. For
# example, CH3NH2 is named as methanamine. In case, more than one
# amino group is present at different positions in the parent chain, their
# positions are specified by giving numbers to the carbon atoms bearing
# –NH2 groups and suitable prefix such as di, tri, etc. is attached to the
# amine. The letter ‘e’ of the suffix of the hydrocarbon part is retained. For
# example, H2N–CH2–CH2–NH2 is named as ethane-1, 2-diamine.
# To name secondary and tertiary amines, we use locant N to designate
# substituent attached to a nitrogen atom. For example, CH3 NHCH2CH3 is
#  9.2
#  9.2
#  9.2
#  9.2
#  9.2
# Classification
# Classification
# Classification
# Classification
# Classification
# Fig. 9.1 Pyramidal shape of trimethylamine
# 9.3
# 9.3
# 9.3
# 9.3
# 9.3
# Nomenclature
# Nomenclature
# Nomenclature
# Nomenclature
# Nomenclature
# Reprint 2024-25
#
#
# 261
# Amines
# named as N-methylethanamine and (CH3CH2)3N is named as N, N-
# diethylethanamine. More examples are given in Table 9.1.
# In arylamines, –NH2 group is directly attached to the benzene ring.
# C6H5NH2 is the simplest example of arylamine.  In common system, it
# is known as aniline. It is also an accepted IUPAC name. While naming
# arylamines according to IUPAC system, suffix ‘e’ of arene is replaced by
# ‘amine’. Thus in IUPAC system, C6H5–NH2 is named as benzenamine.
# Common and IUPAC names of some alkylamines and arylamines are
# given in Table 9.1.
# Amine
# Common name
# IUPAC name
# CH3-–CH2–NH2
# Ethylamine
# Ethanamine
# CH3–CH2–CH2–NH2
# n-Propylamine
# Propan-1-amine
# Isopropylamine
# Propan-2-amine
# Ethylmethylamine
# N-Methylethanamine
# Trimethylamine
# N,N-Dimethylmethanamine
# N,N-Diethylbutylamine
# N,N-Diethylbutan-1-amine
# Allylamine
# Prop-2-en-1-amine
# Hexamethylenediamine
# Hexane-1,6-diamine
# Aniline
# Aniline or Benzenamine
# o-Toluidine
# 2-Methylaniline
# p-Bromoaniline
# 4-Bromobenzenamine
# or
# 4-Bromoaniline
# N,N-Dimethylaniline
# N,N-Dimethylbenzenamine
# Table 9.1: Nomenclature of Some Alkylamines and Arylamines
# Reprint 2024-25
#
#
# 262
# Chemistry
# Amines are prepared by the following methods:
# 1. Reduction of nitro compounds
# Nitro compounds are reduced to amines by passing hydrogen gas
# in the presence of finely divided nickel, palladium or platinum and
# also by reduction with metals in acidic medium. Nitroalkanes can
# also be similarly reduced to the corresponding alkanamines.
# Reduction with iron scrap and hydrochloric acid is preferred because
# FeCl2 formed gets hydrolysed to release hydrochloric acid during the
# reaction. Thus, only a small amount of hydrochloric acid is required
# to initiate the reaction.
# 2. Ammonolysis of alkyl halides
# You have read (Unit 6, Class XII) that the carbon - halogen bond in
# alkyl or benzyl halides can be easily cleaved by a nucleophile.  Hence,
# an alkyl or benzyl halide on reaction with an ethanolic solution of
# ammonia undergoes nucleophilic substitution reaction in which the
# halogen atom is replaced by an amino (–NH2) group. This process of
# cleavage of the C–X bond by ammonia molecule is known as
# ammonolysis.  The reaction is carried out in a sealed tube at 373
# K.  The primary amine thus obtained behaves as a nucleophile and
# can further react with alkyl halide to form secondary and tertiary
# amines, and finally quaternary ammonium salt.
# 9.4
# 9.4
# 9.4
# 9.4
# 9.4 Preparation
# Preparation
# Preparation
# Preparation
# Preparation
# of Amines
# of Amines
# of Amines
# of Amines
# of Amines
# 9.1
# Classify the following amines as primary, secondary or tertiary:
# 9.2
# (i) Write structures of different isomeric amines corresponding to the molecular
# formula, C4H11N.
# (ii) Write IUPAC names of all the isomers.
# (iii) What type of isomerism is exhibited by different pairs of amines?
# Intext Questions
# Intext Questions
# Intext Questions
# Intext Questions
# Intext Questions
# Reprint 2024-25
#
#
# 263
# Amines
# The free amine can be obtained from the ammonium salt by treatment
# with a strong base:
# Ammonolysis has the disadvantage of yielding a mixture of primary,
# secondary and tertiary amines and also a quaternary ammonium salt.
# However, primary amine is obtained as a major product by taking
# large excess of ammonia.
# The order of reactivity of halides with amines is RI > RBr >RCl.
# 3. Reduction of nitriles
# Nitriles on reduction with lithium aluminium hydride (LiAlH4) or
# catalytic hydrogenation produce primary amines. This reaction is
# used for ascent of amine series, i.e., for preparation of amines
# containing one carbon atom more than the starting amine.
# 4. Reduction of amides
# The amides on reduction with lithium aluminium hydride yield
# amines.
# Example 9.1
# Example 9.1
# Example 9.1
# Example 9.1
# Example 9.1
# Solution
# Solution
# Solution
# Solution
# Solution
# Write chemical equations for the following reactions:
# (i) Reaction of ethanolic NH3 with C2H5Cl.
# (ii) Ammonolysis of benzyl chloride and reaction of amine so formed
# with two moles of CH3Cl.
# Reprint 2024-25
#
#
# 264
# Chemistry
# 5. Gabriel phthalimide synthesis
# Gabriel synthesis is used for the preparation of primary amines.
# Phthalimide on treatment with ethanolic potassium hydroxide forms
# potassium salt of phthalimide which on heating with alkyl halide
# followed by alkaline hydrolysis produces the corresponding primary
# amine. Aromatic primary amines cannot be prepared by this method
# because aryl halides do not undergo nucleophilic substitution with
# the anion formed by phthalimide.
# 6. Hoffmann bromamide degradation reaction
# Hoffmann developed a method for preparation of primary amines by
# treating an amide with bromine in an aqueous or ethanolic solution
# of sodium hydroxide.  In this degradation reaction, migration of an
# alkyl or aryl group takes place from carbonyl carbon of the amide
# to the nitrogen atom. The amine so formed contains one carbon less
# than that present in the amide.
# Write chemical equations for the following conversions:
# (i) CH3–CH2–Cl into CH3–CH2–CH2–NH2
# (ii) C6H5–CH2–Cl into C6H5–CH2–CH2–NH2
# Example 9.2
# Example 9.2
# Example 9.2
# Example 9.2
# Example 9.2
# Solution
# Solution
# Solution
# Solution
# Solution
# Reprint 2024-25
#
#
# 265
# Amines
# The lower aliphatic amines are gases with fishy odour. Primary amines
# with three or more carbon atoms are liquid and still higher ones are
# solid. Aniline and other arylamines are usually colourless but get
# coloured on storage due to atmospheric oxidation.
# Lower aliphatic amines are soluble in water because they can form
# hydrogen bonds with water molecules. However, solubility decreases
# with increase in molar mass of amines due to increase in size of the
# hydrophobic alkyl part. Higher amines are essentially insoluble in water.
# Considering the electronegativity of nitrogen of amine and oxygen of
# alcohol as 3.0 and 3.5 respectively, you can  predict the pattern of
# solubility of amines and alcohols in water.  Out of butan-1-ol and
# butan-1-amine, which will be more soluble in water and why?  Amines
# are soluble in organic solvents like alcohol, ether and benzene. You
# may remember that alcohols are more polar than amines and form
# stronger intermolecular hydrogen bonds than amines.
# Primary and secondary amines are engaged in intermolecular
# association due to hydrogen bonding between nitrogen of one and
# hydrogen of another molecule. This intermolecular association is more
# in primary amines than in secondary amines as there are two hydrogen
# atoms available for hydrogen bond formation in it. Tertiary amines do
# not have intermolecular association due to the absence of hydrogen
# atom available for hydrogen bond formation. Therefore, the order of
# boiling points of isomeric amines is as follows:
# 9.5
# 9.5
# 9.5
# 9.5
# 9.5 Physical
# Physical
# Physical
# Physical
# Physical
# Properties
# Properties
# Properties
# Properties
# Properties
# 9.3
# How will you convert
# (i) Benzene into aniline  (ii) Benzene into N, N-dimethylaniline
# (iii) Cl–(CH2)4–Cl into hexan-1,6-diamine?
# Intext Question
# Intext Question
# Intext Question
# Intext Question
# Intext Question
# Write structures and IUPAC names of
# (i) the amide which gives propanamine by Hoffmann bromamide
# reaction.
# (ii) the amine produced by the Hoffmann degradation of benzamide.
# (i) Propanamine contains three carbons.  Hence, the amide molecule must
# contain four carbon atoms. Structure and IUPAC name of the starting
# amide with four carbon atoms are given below:
# Butanamide
# (ii) Benzamide is an aromatic amide containing seven carbon atoms.
# Hence, the amine formed from benzamide is aromatic primary amine
# containing six carbon atoms.
# Aniline or benzenamine
# Example 9.3
# Example 9.3
# Example 9.3
# Example 9.3
# Example 9.3
# Solution
# Solution
# Solution
# Solution
# Solution
# Reprint 2024-25
#
#
# 266
# Chemistry
# Primary > Secondary > Tertiary
# Intermolecular hydrogen bonding in primary amines is shown in
# Fig. 9.2.
# Boiling points of amines, alcohols and alkanes of almost the same
# molar mass are shown in Table 9.2.
# Fig. 9.2 Intermolecular hydrogen bonding in primary amines
# Table 9.2:
# Comparison of Boiling Points of Amines, Alcohols and
# Alkanes of Similar Molecular Masses
# Sl. No.
# Compound
# Molar mass
# b.p./K
# 1.
# n-C4H9NH2
# 73
# 350.8
# 2.
# (C2H5)2NH
# 73
# 329.3
# 3.
# C2H5N(CH3)2
# 73
# 310.5
# 4.
# C2H5CH(CH3)2
# 72
# 300.8
# 5.
# n-C4H9OH
# 74
# 390.3
# Difference in electronegativity between nitrogen and hydrogen atoms and
# the presence of unshared pair of electrons over the nitrogen atom makes
# amines reactive. The number of hydrogen atoms attached to nitrogen
# atom also decides the course of reaction of amines; that is why primary
# (–NH2), secondary
# N
# H  and tertiary amines
# N
# differ in many
# reactions.  Moreover, amines behave as nucleophiles due to the presence
# of unshared electron pair.  Some of the reactions of amines are described
# below:
# 1. Basic character of amines
# Amines, being basic in nature, react with acids to form salts.
# 9.6
# 9.6
# 9.6
# 9.6
# 9.6 Chemical
# Chemical
# Chemical
# Chemical
# Chemical
# Reactions
# Reactions
# Reactions
# Reactions
# Reactions
# Reprint 2024-25
#
#
# 267
# Amines
# Amine salts on treatment with a base like NaOH, regenerate the
# parent amine.
# Amine salts are soluble in water but insoluble in organic solvents
# like ether. This reaction is the basis for the separation of amines from
# the non basic organic compounds insoluble in water.
# The reaction of amines with mineral acids to form ammonium salts
# shows that these are basic in nature. Amines have an unshared pair
# of electrons on nitrogen atom due to which they behave as Lewis base.
# Basic character of amines can be better understood in terms of their Kb
# and pKb values as explained below:
# K = 
# 
# 
# 3
# 2
# 2
# R
# OH
# R
# H
# NH
# NH
# O
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 2
# or
# [H O]
# K
# =
# 
# 
# 3
# 2
# O
# H
# N H
# H
# R
# R
# N
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# or
# b
# K
# =
# 
# 
# 3
# 2
# O
# N H
# NH
# H
# R
# R
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# pKb = –log Kb
# Larger the value of Kb or smaller the value of pKb, stronger is the
# base. The pKb values of few amines are given in Table 9.3.
# pKb value of ammonia is 4.75. Aliphatic amines are stronger bases
# than ammonia due to +I effect of alkyl groups leading to high electron
# density on the nitrogen atom.  Their pKb values lie in the range of 3 to
# 4.22. On the other hand, aromatic amines are weaker bases than
# ammonia due to the electron withdrawing nature of the aryl group.
# Name of amine
# pKb
# Methanamine
# 3.38
# N-Methylmethanamine
# 3.27
# N,N-Dimethylmethanamine
# 4.22
# Ethanamine
# 3.29
# N-Ethylethanamine
# 3.00
# N,N-Diethylethanamine
# 3.25
# Benzenamine
# 9.38
# Phenylmethanamine
# 4.70
# N-Methylaniline
# 9.30
# N,N-Dimethylaniline
# 8.92
#  Table 9.3:  pKb Values of Amines in Aqueous Phase
# Reprint 2024-25
#
#
# 268
# Chemistry
# You may find some discrepancies while trying to interpret the Kb
# values of amines on the basis of  +I or –I effect of the substituents
# present in amines.  Besides inductive effect, there are other effects like
# solvation effect, steric hinderance, etc., which affect the basic strength
# of amines. Just ponder over. You may get the answer in the following
# paragraphs.
# Structure-basicity relationship of amines
# Basicity of amines is related to their structure.  Basic character of an
# amine depends upon the ease of formation of the cation by accepting
# a proton from the acid.  The more stable the cation is relative to the
# amine, more basic is the amine.
# (a) Alkanamines versus ammonia
# Let us consider the reaction of an alkanamine and ammonia with
# a proton to compare their basicity.
# Due to the electron releasing nature of alkyl group, it (R) pushes
# electrons towards nitrogen and thus makes the unshared electron
# pair more available for sharing with the proton of the acid. Moreover,
# the substituted ammonium ion formed from the amine gets stabilised
# due to dispersal of the positive charge by the +I effect of the alkyl
# group.  Hence, alkylamines are stronger bases than ammonia.
# Thus, the basic nature of aliphatic amines should increase with
# increase in the number of alkyl groups. This trend is followed in
# the gaseous phase. The order of basicity of amines in the gaseous
# phase follows the expected order: tertiary amine > secondary amine
# > primary amine > NH3. The trend is not regular in the aqueous
# state as evident by their pKb values given in Table 9.3. In the
# aqueous phase, the substituted ammonium cations get stabilised
# not only by electron releasing effect of the alkyl group (+I) but also
# by solvation with water molecules. The greater the size of the ion,
# lesser will be the solvation and the less stabilised is the ion. The
# order of stability of ions are as follows:
# Decreasing order of  extent of H-bonding in water and order of
# stability of ions by solvation.
# Reprint 2024-25
#
#
# 269
# Amines
# Greater is the stability of the substituted ammonium cation, stronger
# should be the corresponding amine as a base. Thus, the order of basicity
# of aliphatic amines should be: primary > secondary > tertiary, which
# is opposite to the inductive effect based order.   Secondly, when the
# alkyl group is small, like –CH3 group, there is no steric hindrance to
# H-bonding. In case the alkyl group is bigger than CH3 group, there will
# be steric hinderance to H-bonding. Therefore,  the change of nature of
# the alkyl group, e.g., from –CH3 to –C2H5 results in change of the order
# of basic strength. Thus, there is a subtle interplay of the inductive
# effect, solvation effect and steric hinderance of the alkyl group which
# decides the basic strength of alkyl amines in the aqueous state.  The
# order of basic strength in case of methyl substituted amines and ethyl
# substituted amines in aqueous solution is as follows:
# (C2H5)2NH > (C2H5)3N > C2H5NH2 > NH3
# (CH3)2NH > CH3NH2 > (CH3)3N > NH3
# (b) Arylamines versus ammonia
# pKb value of aniline is quite high.  Why is it so?  It is because in
# aniline or other arylamines, the -NH2 group is attached directly to
# the benzene ring. It results in the unshared electron pair on nitrogen
# atom to be in conjugation with the benzene ring and thus making
# it less available for protonation.  If you write different resonating
# structures of aniline,  you will find that aniline is a resonance
# hybrid of the following five structures.
# On the other hand, anilinium ion obtained by accepting a proton
# can have only two resonating structures (kekule).
# We know that greater the number of resonating structures, greater
# is the stability. Thus you can infer that aniline (five resonating
# structures) is more stable than anilinium ion. Hence, the proton
# acceptability or the basic nature of aniline or other aromatic amines
# would be less than that of ammonia.  In case of substituted aniline, it
# is observed that electron releasing groups like –OCH3, –CH3 increase
# basic strength whereas electron withdrawing groups like  –NO2, –SO3H,
# –COOH, –X decrease it.
# Reprint 2024-25
#
#
# 270
# Chemistry
# 2. Alkylation
# Amines undergo alkylation on reaction with alkyl halides (refer Unit
# 6, Class XII).
# 3. Acylation
# Aliphatic and aromatic primary and secondary amines react with
# acid chlorides, anhydrides and esters by nucleophilic substitution
# reaction.  This reaction is known as acylation.  You can consider
# this reaction as the replacement of hydrogen atom of –NH2 or >N–H
# group by the acyl group. The products obtained by acylation reaction
# are known as amides. The reaction is carried out in the presence of
# a base stronger than the amine, like pyridine, which removes HCl so
# formed and shifts the equilibrium to the right hand side.
# Amines also react with benzoyl chloride (C6H5COCl).  This reaction
# is known as benzoylation.
# 3
# 6
# 5
# 6
# 5
# 2
# 3
# Methanamine
# Benzoyl chloride
# N
# Methylbenzamide
# NH
# C C
# O
# CH
# C H
# CH
# C H
# H l
# NH
# l
# C
# C
# O
# 
# 
# 
# 
# What do you think is the product of the reaction of amines with
# carboxylic acids ? They form salts with amines at room temperature.
# Arrange the following in decreasing order of their basic strength:
# C6H5NH2, C2H5NH2, (C2H5)2NH,  NH3
# The decreasing order of basic strength of the above amines and ammonia
# follows the following order:
# (C2H5)2NH > C2H5NH2 > NH3 >  C6H5NH2
# Example 9.4
# Example 9.4
# Example 9.4
# Example 9.4
# Example 9.4
# Solution
# Solution
# Solution
# Solution
# Solution
# Reprint 2024-25
#
#
# 271
# Amines
# S
# O
# O
# Cl
# +
# H
# N
# C H
# 2
# 5
# S
# O
# O
# N
# C H
# 2
# 5 + HCl
# N,N-Diethylbenzenesulphonamide
# C H
# 2
# 5
# C H
# 2
# 5
# 4. Carbylamine reaction
# Aliphatic and aromatic primary amines on heating with chloroform
# and ethanolic potassium hydroxide form isocyanides or carbylamines
# which are foul smelling substances.  Secondary and tertiary amines
# do not show this reaction.  This reaction is known as carbylamine
# reaction or isocyanide test and is used as a test for primary amines.
# 5. Reaction with nitrous acid
# Three classes of amines react differently with nitrous acid which is
# prepared in situ from a mineral acid and sodium nitrite.
# (a) Primary aliphatic amines react with nitrous acid to form aliphatic
# diazonium salts which being unstable, liberate nitrogen gas
# quantitatively and alcohols. Quantitative evolution of nitrogen is
# used in estimation of amino acids and proteins.
# (b) Aromatic amines react with nitrous acid at low temperatures
# (273-278 K) to form diazonium salts, a very important class of
# compounds used for synthesis of a variety of aromatic compounds
# discussed in Section 9.7.
# Secondary and tertiary amines react with nitrous acid in a
# different manner.
# 6. Reaction with arylsulphonyl chloride
# Benzenesulphonyl chloride (C6H5SO2Cl), which is also known as
# Hinsberg’s reagent, reacts with primary and secondary amines to
# form sulphonamides.
# (a) The reaction of benzenesulphonyl chloride with primary amine
# yields N-ethylbenzenesulphonyl amide.
# The hydrogen attached to nitrogen in sulphonamide is strongly
# acidic due to the presence of strong electron withdrawing sulphonyl
# group. Hence, it is soluble in alkali.
# (b) In the reaction with secondary amine, N,N-diethyl-
# benzenesulphonamide is formed.
# Reprint 2024-25
#
#
# 272
# Chemistry
# Since N, N-diethylbenzene sulphonamide does not contain any
# hydrogen atom attached to nitrogen atom, it is not acidic and hence
# insoluble in alkali.
# (c) Tertiary amines do not react with benzenesulphonyl chloride.
# This property of amines reacting with benzenesulphonyl chloride
# in a different manner is used for the distinction of primary,
# secondary and tertiary amines and also for the separation of a
# mixture of amines. However, these days benzenesulphonyl
# chloride is replaced by p-toluenesulphonyl chloride.
# 7. Electrophilic substitution
# You have read earlier that aniline is a resonance hybrid of five
# structures. Where do you find the maximum electron density in
# these structures? Ortho- and para-positions to the –NH2 group
# become centres of high electron density.  Thus –NH2 group is ortho
# and para directing and a powerful activating group.
# (a) Bromination: Aniline reacts with bromine water at room
# temperature to give a white precipitate of 2,4,6-tribromoaniline.
# The main problem encountered during electrophilic substitution
# reactions of aromatic amines is that of their very high reactivity.
# Substitution tends to occur at ortho- and para-positions.  If we
# have to prepare monosubstituted  aniline derivative, how can
# the activating effect of –NH2 group be controlled ?  This can be
# done by protecting the -NH2 group by acetylation with acetic
# anhydride, then carrying out the desired substitution followed
# by hydrolysis of the substituted amide to the substituted amine.
# The lone pair of electrons on nitrogen of acetanilide  interacts
# with oxygen atom due to resonance as shown below:
# Reprint 2024-25
#
#
# 273
# Amines
# Hence, the lone pair of electrons on nitrogen is less available for
# donation to benzene ring by  resonance. Therefore, activating
# effect of –NHCOCH3 group is less than that of amino group.
# (b) Nitration: Direct nitration of aniline yields tarry oxidation
# products in addition to the nitro derivatives. Moreover, in the
# strongly acidic medium, aniline is protonated to form the
# anilinium ion which is meta directing. That is why besides the
# ortho and para derivatives, significant amount of meta derivative
# is also formed.
# However, by protecting the –NH2 group by acetylation reaction
# with acetic anhydride, the nitration  reaction can be controlled
# and the p-nitro derivative can be obtained as the major product.
# (c) Sulphonation:  Aniline reacts with concentrated sulphuric acid
# to form anilinium hydrogensulphate which on heating with
# sulphuric acid at 453-473K produces p-aminobenzene sulphonic
# acid, commonly known as sulphanilic acid, as the major product.
# Aniline does not undergo Friedel-Crafts reaction (alkylation and
# acetylation) due to salt formation with aluminium chloride, the
# Lewis acid, which is used as a catalyst. Due to this, nitrogen of
# aniline acquires positive charge and hence acts as a strong
# deactivating group for further reaction.
# Reprint 2024-25
#
#
# 274
# Chemistry
# II. DIAZONIUM SALTS
# The diazonium salts have the general formula
# –
# 2
# R N X
# 
#  where R stands
# for an aryl group and
# –
# X  ion may be Cl
# – Br,
# –
# 4
# HSO,
# 4
# BF, etc. They are
# named by suffixing diazonium to the name of the parent hydrocarbon
# from which they are formed, followed by the name of anion such as
# chloride, hydrogensulphate, etc. The
# 2
# N
#  group is called diazonium
# group. For example,
# –
# 2
# 6
# 5
# C H
# N
# Cl
# 
#  is named as benzenediazonium
# chloride and C6H5N2
# +HSO4
# – is known as benzenediazonium
# hydrogensulphate.
# Primary aliphatic amines form highly unstable alkyldiazonium salts
# (refer to Section 9.6). Primary aromatic amines form arenediazonium
# salts which are stable for a short time in solution at low temperatures
# (273-278 K). The stability of arenediazonium ion is explained on the
# basis  of resonance.
# Benzenediazonium chloride is prepared by the reaction of aniline with
# nitrous acid at 273-278K. Nitrous acid is produced in the reaction
# mixture by the reaction of sodium nitrite with hydrochloric acid. The
# conversion of primary aromatic amines into diazonium salts is known
# as diazotisation. Due to its instability, the diazonium salt is not
# generally stored and is used immediately after its preparation.
# 
# 
# 
# 
# 
# 
# 
# 2
# 273 278K
# 6
# 5
# 2
# –
# 6
# 5
# 2
# 2
# C H
# NaNO
# 2H
# C H
# Na
# Cl
# Cl
# Cl
# H
# N
# 2H
# N
# O
# Intext Questions
# Intext Questions
# Intext Questions
# Intext Questions
# Intext Questions
# 9.4
# Arrange the following in increasing order of their basic strength:
# (i) C2H5NH2, C6H5NH2, NH3, C6H5CH2NH2 and (C2H5)2NH
# (ii) C2H5NH2, (C2H5)2NH, (C2H5)3N, C6H5NH2
# (iii) CH3NH2, (CH3)2NH, (CH3)3N, C6H5NH2, C6H5CH2NH2.
# 9.5
# Complete the following acid-base reactions and name the products:
# (i) CH3CH2CH2NH2 + HCl ®
# (ii) (C2H5)3N + HCl  ®
# 9.6
# Write reactions of the final alkylation product of aniline with excess of methyl
# iodide in the presence of sodium carbonate solution.
# 9.7
# Write chemical reaction of aniline with benzoyl chloride and write the name of
# the product obtained.
# 9.8
# Write structures of different isomers corresponding to the molecular formula,
# C3H9N. Write IUPAC names of the isomers which will liberate nitrogen gas on
# treatment with nitrous acid.
# 9.7
# 9.7
# 9.7
# 9.7
# 9.7 Method of
# Method of
# Method of
# Method of
# Method of
# Preparation
# Preparation
# Preparation
# Preparation
# Preparation
# of Diazoniun
# of Diazoniun
# of Diazoniun
# of Diazoniun
# of Diazoniun
# Salts
# Salts
# Salts
# Salts
# Salts
# Reprint 2024-25
#
#
# 275
# Amines
# Benzenediazonium chloride is a colourless crystalline solid. It is readily
# soluble in water and is stable in cold but reacts with water when
# warmed. It decomposes easily in the dry state. Benzenediazonium
# fluoroborate is water insoluble and stable at room temperature.
# The reactions of diazonium salts can be broadly divided into two
# categories, namely (A) reactions involving displacement of nitrogen and
# (B) reactions involving retention of diazo group.
# A. Reactions involving displacement of nitrogen
# Diazonium group being a very good leaving group, is substituted
# by other groups such as Cl
# –, Br
# –
# , I
# –
# , CN
# –
#  and OH
# – which displace
# nitrogen from the aromatic ring. The nitrogen  formed escapes from
# the reaction mixture as a gas.
# 1. Replacement by halide or cyanide ion: The Cl
# –, Br
# – and CN
# –
# nucleophiles can easily be introduced in the benzene ring in the
# presence of Cu(I) ion. This reaction is called Sandmeyer reaction.
# Alternatively, chlorine or bromine can also be introduced in the
# benzene ring by treating the diazonium salt solution with corresponding
# halogen acid in the presence of copper powder. This is referred as
# Gatterman reaction.
# The yield in Sandmeyer reaction is found to be better than
# Gattermann reaction.
# 2. Replacement by iodide ion: Iodine is not easily introduced into
# the benzene ring directly, but, when the diazonium salt solution
# is treated with potassium iodide, iodobenzene is formed.
# 3. Replacement by fluoride ion: When arenediazonium chloride is
# treated with fluoroboric acid, arene diazonium fluoroborate is
# precipitated  which on heating decomposes to yield aryl fluoride.
# 4. Replacement by H: Certain mild reducing agents like
# hypophosphorous acid (phosphinic acid) or ethanol reduce
# diazonium salts to arenes and themselves get oxidised to
# phosphorous acid and ethanal, respectively.
# 9.8
# 9.8
# 9.8
# 9.8
# 9.8
# Physical
# Physical
# Physical
# Physical
# Physical
# Properties
# Properties
# Properties
# Properties
# Properties
# 9.9
# 9.9
# 9.9
# 9.9
# 9.9 Chemical
# Chemical
# Chemical
# Chemical
# Chemical
# Reactions
# Reactions
# Reactions
# Reactions
# Reactions
# 2
# 2
# 2
# 2
# Reprint 2024-25
#
#
# 276
# Chemistry
# 5. Replacement by hydroxyl group: If the temperature of the
# diazonium salt solution is allowed to rise  upto 283 K, the salt
# gets hydrolysed to phenol.
# 6. Replacement by –NO2 group: When diazonium fluoroborate is
# heated with aqueous sodium nitrite solution in the presence of
# copper, the diazonium group is replaced by –NO2 group.
# B. Reactions involving retention of diazo group
# coupling reactions
# The azo products obtained have an extended conjugate system having
# both the aromatic rings joined through the –N=N– bond. These compounds
# are often coloured and are used as dyes. Benzene diazonium chloride
# reacts with phenol in which the phenol molecule at its para position is
# coupled with the diazonium salt to form p-hydroxyazobenzene. This
# type of reaction is known as coupling reaction. Similarly the reaction of
# diazonium salt with aniline yields p-aminoazobenzene. This is an example
# of electrophilic substitution reaction.
# From the above reactions, it is clear that the diazonium salts are very
# good intermediates for the introduction of –F, –Cl, –Br, –I, –CN, –OH,
# –NO2 groups into the aromatic ring.
# Aryl fluorides and iodides cannot be prepared by direct halogenation.
# The cyano group cannot be introduced by nucleophilic substitution of
# chlorine in chlorobenzene but cyanobenzene can be easily obtained
# from diazonium salt.
# Thus, the replacement of diazo group by other groups is helpful in
# 9.10
# .10
# .10
# .10
# .10 Importance
# Importance
# Importance
# Importance
# Importance
# ofofofofof Diazonium
# Diazonium
# Diazonium
# Diazonium
# Diazonium
# Salts in
# Salts in
# Salts in
# Salts in
# Salts in
# Synthesis
# Synthesis
# Synthesis
# Synthesis
# Synthesis
# of Aromatic
# of Aromatic
# of Aromatic
# of Aromatic
# of Aromatic
# Compounds
# Compounds
# Compounds
# Compounds
# Compounds
# Reprint 2024-25
#
#
# 277
# Amines
# preparing those substituted aromatic compounds which cannot be
# prepared by direct substitution in benzene or substituted benzene.
# 9.9
# Convert
# (i) 3-Methylaniline into 3-nitrotoluene.
# (ii) Aniline into 1,3,5 - tribromobenzene.
# Intext Question
# Intext Question
# Intext Question
# Intext Question
# Intext Question
# How will you convert 4-nitrotoluene to 2-bromobenzoic acid ?
# Example 9.5
# Example 9.5
# Example 9.5
# Example 9.5
# Example 9.5
# Solution
# Solution
# Solution
# Solution
# Solution
# Amines can be considered as derivatives of ammonia obtained by replacement of
# hydrogen atoms with alkyl or aryl groups. Replacement of one hydrogen atom of
# ammonia gives rise to structure of the type R-NH2, known as primary amine.
# Secondary amines are characterised by the structure R2NH or R-NHR¢ and tertiary
# amines by R3N, RNR¢R¢¢¢¢¢¢¢¢¢¢ or R2NR¢.¢.¢.¢.¢.  Secondary and tertiary amines are known as
# simple amines if the alkyl or aryl groups are the same and mixed amines if the
# groups are different. Like ammonia, all the three types of amines have one unshared
# electron pair on nitrogen atom due to which they behave as Lewis bases.
# Amines are usually formed from nitro compounds, halides, amides, imides, etc.
# They exhibit hydrogen bonding which influence their physical properties. In
# alkylamines, a combination of electron releasing, steric and H-bonding factors
# influence the stability of the substituted ammonium cations in protic polar solvents
# and thus affect the basic nature of amines. Alkyl amines are found to be stronger
# bases than ammonia. In aromatic amines, electron releasing and withdrawing groups,
# respectively increase and decrease their basic character. Aniline is a weaker base
# Summary
# Summary
# Summary
# Summary
# Summary
# Reprint 2024-25
#
#
# 278
# Chemistry
# than ammonia. Reactions of amines are governed by availability of the unshared pair
# of electrons on nitrogen. Influence of the number of hydrogen atoms at nitrogen atom
# on the type of reactions and nature of products is responsible for identification and
# distinction between primary, secondary and tertiary amines. p-Toluenesulphonyl chloride
# is used for the identification of primary, secondary and tertiary amines. Presence of
# amino group in aromatic ring enhances reactivity of the aromatic amines. Reactivity of
# aromatic amines can be controlled by acylation process, i.e., by treating with acetyl
# chloride or acetic anhydride. Tertiary amines like trimethylamine are used as insect
# attractants.
# Aryldiazonium salts, usually obtained from arylamines, undergo replacement of
# the diazonium group with a variety of nucleophiles to provide advantageous methods
# for producing aryl halides, cyanides, phenols and  arenes by reductive removal of the
# diazo group. Coupling reaction of aryldiazonium salts with phenols or arylamines give
# rise to the formation of azo dyes.
# 9.1
# Write IUPAC names of the following compounds and classify them into primary,
# secondary and tertiary amines.
# (i) (CH3)2CHNH2
# (ii) CH3(CH2)2NH2
# (iii) CH3NHCH(CH3)2
# (iv) (CH3)3CNH2
# (v) C6H5NHCH3
# (vi) (CH3CH2)2NCH3
# (vii) m–BrC6H4NH2
# 9.2
# Give one chemical test to distinguish between the following pairs of compounds.
# (i) Methylamine and dimethylamine
# (ii) Secondary and tertiary amines
# (iii) Ethylamine and aniline
# (iv) Aniline and benzylamine
# (v) Aniline and N-methylaniline.
# 9.3
# Account for the following:
# (i) pKb of aniline is more than that of methylamine.
# (ii) Ethylamine is soluble in water whereas aniline is not.
# (iii) Methylamine in water reacts with ferric chloride to precipitate hydrated
# ferric oxide.
# (iv) Although amino group is o– and p– directing in aromatic electrophilic
# substitution reactions, aniline on nitration gives a substantial amount of
# m-nitroaniline.
# (v) Aniline does not undergo Friedel-Crafts reaction.
# (vi) Diazonium salts of aromatic amines are more stable than those of aliphatic
# amines.
# (vii) Gabriel phthalimide synthesis is preferred for synthesising primary amines.
# 9.4
# Arrange the following:
# (i) In decreasing order of the pKb values:
# C2H5NH2, C6H5NHCH3, (C2H5)2NH and C6H5NH2
# (ii) In increasing order of basic strength:
# C6H5NH2, C6H5N(CH3)2, (C2H5)2NH and CH3NH2
# (iii) In increasing order of basic strength:
# (a) Aniline, p-nitroaniline and p-toluidine
# Exercises
# Reprint 2024-25
#
#
# 279
# Amines
# (b) C6H5NH2, C6H5NHCH3, C6H5CH2NH2.
# (iv) In decreasing order of basic strength in gas phase:
# C2H5NH2, (C2H5)2NH, (C2H5)3N and NH3
# (v) In increasing order of boiling point:
# C2H5OH, (CH3)2NH, C2H5NH2
# (vi) In increasing order of solubility in water:
# C6H5NH2, (C2H5)2NH, C2H5NH2.
# 9.5
# How will you convert:
# (i) Ethanoic acid into methanamine
# (ii) Hexanenitrile into 1-aminopentane
# (iii) Methanol to ethanoic acid
# (iv) Ethanamine into methanamine
# (v) Ethanoic acid into propanoic acid
# (vi) Methanamine into ethanamine
# (vii) Nitromethane into dimethylamine
# (viii) Propanoic acid into ethanoic acid?
# 9.6
# Describe a method for the identification of primary, secondary and tertiary amines.
# Also write chemical equations of the reactions involved.
# 9.7
# Write short notes on the following:
# (i) Carbylamine reaction
# (ii) Diazotisation
# (iii) Hofmann’s bromamide reaction
# (iv) Coupling reaction
# (v) Ammonolysis
# (vi) Acetylation
# (vii) Gabriel phthalimide synthesis.
# 9.8
# Accomplish the following conversions:
# (i) Nitrobenzene to benzoic acid
# (ii) Benzene to m-bromophenol
# (iii) Benzoic acid to aniline
# (iv) Aniline to 2,4,6-tribromofluorobenzene
# (v) Benzyl chloride to 2-phenylethanamine
# (vi) Chlorobenzene to p-chloroaniline
# (vii) Aniline to p-bromoaniline
# (viii) Benzamide to toluene
# (ix) Aniline to benzyl alcohol.
# 9.9
# Give the structures of A, B and C in the following reactions:
# (i)
# 2
# NaOH Br
# NaCN
# OH
# 3
# 2
# Partial hydrolysis
# CH CH I
# A
# B
# C
# 
# 
# 
# 
# 
# (ii)
# 3
# 2
# NH
# H O/H
# CuCN
# 6
# 5
# 2
# C H N Cl
# A
# B
# C
# 
# 
# 
# 
# 
# (iii)
# 4
# 2
# LiAlH
# HNO
# KCN
# 3
# 2
# 0 C
# CH CH Br
# A
# B
# C
# 
# 
# 
# 
# (iv)
# 2
# 2
# NaNO
# HCl
# H O/H
# Fe /HCl
# 6
# 5
# 2
# 273 K
# C H NO
# A
# B
# C
# 
# 
# 
# 
# 
# 
# (v)
# 3
# 2
# NH
# NaNO /HCl
# NaOBr
# 3
# CH COOH
# A
# B
# C
# 
# 
# 
# 
# (vi)
# 6
# 5
# 2
# C H OH
# HNO
# Fe/HCl
# 6
# 5
# 2
# 273K
# C H NO
# A
# B
# C
# 
# 
# 
# Reprint 2024-25
#
#
# 280
# Chemistry
# 9.10
# An aromatic compound ‘A’ on treatment with aqueous ammonia and heating
# forms compound ‘B’ which on heating with Br2 and KOH forms a compound ‘C’
# of molecular formula C6H7N. Write the structures and IUPAC names of compounds
# A, B and C.
# 9.11
# Complete the following reactions:
# (i)
# 6
# 5
# 2
# 3
# C H NH
# CHCl
# alc.KOH
# 
# 
# 
# (ii)
# 6
# 5
# 2
# 3
# 2
# 2
# C H N Cl
# H PO
# H O
# 
# 
# 
# (iii)
# 
# 
# 6
# 5
# 2
# 2
# 4
# C H NH
# H SO
# conc.
# 
# 
# (iv)
# 6
# 5
# 2
# 2
# 5
# C H N Cl
# C H OH
# 
# 
# (v)
# 
# 
# 6
# 5
# 2
# 2
# C H NH
# Br
# aq
# 
# 
# (vi)
# 
# 
# 3
# 6
# 5
# 2
# 2
# CH CO
# C H NH
# O
# 
# 
# (vii)
# 
# 
# 4
# 2
# HBF
# i
# 6
# 5
# 2
# NaNO /Cu,
# ii
# C H N Cl
# 
# 
# 9.12
# Why cannot aromatic primary amines be prepared by Gabriel phthalimide
# synthesis?
# 9.13
# Write the reactions of (i) aromatic and (ii) aliphatic primary amines with nitrous
# acid.
# 9.14
# Give plausible explanation for each of the following:
# (i) Why are amines less acidic than alcohols of comparable  molecular masses?
# (ii) Why do primary amines have higher boiling point than tertiary amines?
# (iii) Why are aliphatic amines stronger bases than aromatic amines?
# Answers to Some Intext Questions
# 9.4
# (i) C6H5NH2 < NH3 < C6H5CH2NH2 < C2H5NH2 < (C2H5)2NH
# (ii) C6H5NH2 < C2H5NH2. < (C2H5)3N < (C2H5)2NH
# (iii) C6H5NH2 < C6H5CH2NH2 < (CH3)3N < CH3NH2 < (CH3)2NH
# Reprint 2024-25
#
#   -> Document loaded successfully.
# [2/7] Splitting text into chunks...
#   -> Document split into 44 chunks.
# [3/7] Creating embeddings and vector store...
# /var/folders/yn/7wm3zbp54gxbjlhxp3g95rg80000gn/T/ipykernel_72857/3688618032.py:98: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
#   -> Vector store created.
# [4/7] Summarizing 44 chunks concurrently (limit: 200)...
#   -> Error summarizing chunk 30: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
#   -> Error summarizing chunk 13: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
#   -> Error summarizing chunk 38: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
#   -> Error summarizing chunk 14: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
#   -> Error summarizing chunk 26: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
#   -> Error summarizing chunk 19: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
#   -> Error summarizing chunk 35: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
#   -> Error summarizing chunk 20: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
#   -> Error summarizing chunk 17: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
# ...
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
#   -> Error summarizing chunk 4: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
#   -> Error summarizing chunk 1: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
#   -> Error summarizing chunk 39: 429 Resource has been exhausted (e.g. check quota).
#   -> Error summarizing chunk 28: 429 Resource has been exhausted (e.g. check quota).
#   -> Error summarizing chunk 37: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
#   -> Error summarizing chunk 9: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
#   -> Error summarizing chunk 5: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
#   -> Error summarizing chunk 44: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
#   -> Error summarizing chunk 21: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
#   -> Error summarizing chunk 11: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
#   -> Error summarizing chunk 29: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
#   -> Error summarizing chunk 43: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
#   -> Error summarizing chunk 2: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
#   -> Error summarizing chunk 40: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
#   -> Error summarizing chunk 32: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
#   -> Error summarizing chunk 33: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
#   -> Error summarizing chunk 31: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
#   -> All chunks summarized.
# [5/7] Generating retriever questions...
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.11/site-packages/gradio/queueing.py", line 625, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/anaconda3/lib/python3.11/site-packages/gradio/route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/anaconda3/lib/python3.11/site-packages/gradio/blocks.py", line 2220, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/anaconda3/lib/python3.11/site-packages/gradio/blocks.py", line 1731, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/anaconda3/lib/python3.11/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/anaconda3/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 2134, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/opt/homebrew/anaconda3/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 851, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/anaconda3/lib/python3.11/site-packages/gradio/utils.py", line 894, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/var/folders/yn/7wm3zbp54gxbjlhxp3g95rg80000gn/T/ipykernel_72857/3688618032.py", line 182, in sync_wrapper
#     result = asyncio.run(generate_metadata_from_file(input_path))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/anaconda3/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/anaconda3/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "uvloop/loop.pyx", line 1518, in uvloop.loop.Loop.run_until_complete
#   File "/var/folders/yn/7wm3zbp54gxbjlhxp3g95rg80000gn/T/ipykernel_72857/3688618032.py", line 128, in generate_metadata_from_file
#     question_response = llm_model.generate_content(prompt_for_questions)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/anaconda3/lib/python3.11/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 835, in generate_content
#     response = rpc(
#                ^^^^
#   File "/opt/homebrew/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 294, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "/opt/homebrew/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 156, in retry_target
#     next_sleep = _retry_error_helper(
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py", line 214, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/opt/homebrew/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py", line 147, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "/opt/homebrew/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py", line 130, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]

# %%
import google.generativeai as genai
import langchain
from langchain_google_genai import ChatGoogleGenerativeAI
import os
import chromadb
from langchain_community.vectorstores import Chroma
from langchain.embeddings import HuggingFaceEmbeddings
# Import TFIDFRetriever
from langchain_community.retrievers import TFIDFRetriever
from langchain_core.documents import Document
from huggingface_hub import login
import json

# embedding_model = HuggingFaceEmbeddings(model_name="intfloat/multilingual-e5-large")

# with open('/teamspace/studios/this_studio/bhagavad_gita_custom_format (1).json', 'r', encoding='utf-8') as f:
#     gita = json.load(f)

google_api_key = os.getenv("GOOGLE_API_KEY")

genai.configure(api_key=google_api_key)

# llm_model = genai.GenerativeModel("gemini-2.0-flash")
llm_model = ChatGoogleGenerativeAI(model="gemini-2.0-flash")
query = "What is chapter 1 verse 2?"


# prompt1 = f"""You are an expert query analysis bot. Your task is to classify a user's query into one of two categories:

#             1.  **Direct Lookup**: The query is asking for a specific, addressable reference. These queries usually contain identifiers like section numbers, page numbers, document IDs, transaction codes, specific dates, or requests for a definition from a glossary. They feel like a user is trying to "go to" a location.
#             2.  **Semantic Search**: The query is asking a conceptual, thematic, or open-ended question that requires understanding the meaning and context of the text to answer.

#             Based on the user's query, you must decide if it is a 'Direct Lookup'.

#             -- EXAMPLES of Direct Lookup --
#             - "What is described in section 3.4.1 of the report?"
#             - "Show me the maintenance log for transaction ID 'TXN-947-B'."
#             - "Pull up the employee record for E-105."
#             - "What does page 42 say about the budget?"
#             - "Give me the definition for 'Non-Disclosure Agreement'."

#             -- EXAMPLES of Semantic Search --
#             - "What were the main conclusions of the quarterly report?"
#             - "Explain the risks of our new market strategy."
#             - "Compare the pros and cons of the two proposed solutions."
#             - "Summarize our performance last quarter."
#             - "What is our company's policy on remote work?"

#             Now, analyze the following user query.

#             Your response MUST be a single word and nothing else:
#             - 'yes' if the query is a Direct Lookup.
#             - 'no' if the query is a Semantic Search.

#             User Query: {query}"""

prompt1= f"""You are an expert query analysis and keyword extraction bot. Your task is to perform two actions based on a user's query:

            1.  **Classify the query type**:
                * **Direct Lookup**: The query asks for a specific, addressable reference (e.g., section numbers, IDs, page numbers).
                * **Semantic Search**: The query asks a conceptual, thematic, or open-ended question.

            2.  **Extract Search Tags**: Identify and list the most important nouns, concepts, or entities from the query that would be useful for searching a database.

            Your response MUST follow this exact format: [classification,[tag1,tag2,tag3]]
            -   The `classification` MUST be either 'yes' (for Direct Lookup) or 'no' (for Semantic Search).
            -   The tags should be a comma-separated list.
            -   If no specific tags can be extracted, leave the tag list empty (e.g., `[no,[]]`).

            --- EXAMPLES ---
            User Query: "What is chapter 1 verse 2 about dharma?"
            Your Response: [yes,[chapter 1 verse 2,dharma]]

            User Query: "Compare the concepts of action and inaction"
            Your Response: [no,[action,inaction,concepts]]

            User Query: "What is the nature of the Self?"
            Your Response: [no,[Self,nature]]

            User Query: "show me section 3.1.4"
            Your Response: [yes,[section 3.1.4]]

            User Query: "Tell me everything"
            Your Response: [no,[]]
            ---

            Now, analyze the following user query and provide your response in the specified format.

            User Query: {query}"""


response1 = llm_model.invoke(prompt1)

llm_check = response1.content

# if llm_check == "yes":
#     print("Doing Direct Lookup")
#     documents = []
#     for entry in gita:
#         metadata = {
#             'source': entry['source'],
#             'tags': ", ".join(entry['tags']),
#             'full_text': entry['text'],
#             'language': ", ".join(entry['language']),
#             'section': entry['structure']['section'],
#             'chapter': entry['structure']['chapter'],
#             'chapter_number': int(entry['structure']['chapter_number']),
#             'verse_number': int(entry['structure']['verse_number'])
#         }
#         for i in entry['tags']:
#             doc = Document(page_content=i, metadata=metadata)
#             documents.append(doc)

    # --- Step 3: Initialize Retrievers ---

    # Initialize TF-IDF Retriever (Keyword Search)
    # print("Initializing TF-IDF Retriever...")
    # tfidf_retriever = TFIDFRetriever.from_documents(documents)
    # tfidf_retriever.k = 10  # Retrieve top 5 results

    # # Initialize Chroma Vector Store Retriever (Semantic Search)
    # print("Initializing Chroma Vector Store...")
    # chroma_vectorstore = Chroma.from_documents(
    #     documents=documents,
    #     embedding=embedding_model,
    #     persist_directory="./chroma_db_separate" # Using a different directory
    # )
    # # Configure to retrieve top 5 results
    # chroma_retriever = chroma_vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": 10})


    # # --- Step 4: Query each retriever separately ---
    # print(f"\n--- Executing Query: '{query}' ---")


    # # Get and print results from TF-IDF Retriever
    # print("\n--- TF-IDF Keyword Results (Top 5) ---")
    # tfidf_results = tfidf_retriever.get_relevant_documents(query)
    # for doc in tfidf_results:
    #     print(f"- {doc.metadata['full_text']}")


    # # Get and print results from Chroma (Semantic) Retriever
    # print("\n--- Chroma Semantic Results (Top 5) ---")
    # chroma_results = chroma_retriever.get_relevant_documents(query)
    # for doc in chroma_results:
    #     print(f"- {doc.metadata['full_text']}")
# Out:
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised PermissionDenied: 403 Request had insufficient authentication scopes. [reason: "ACCESS_TOKEN_SCOPE_INSUFFICIENT"
# domain: "googleapis.com"
# metadata {
#   key: "method"
#   value: "google.ai.generativelanguage.v1beta.GenerativeService.GenerateContent"
# }
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# ].
# ---------------------------------------------------------------------------
# PermissionDenied                          Traceback (most recent call last)
# Cell In[2], line 93
#      29 # prompt1 = f"""You are an expert query analysis bot. Your task is to classify a user's query into one of two categories:
#      30
#      31 #             1.  **Direct Lookup**: The query is asking for a specific, addressable reference. These queries usually contain identifiers like section numbers, page numbers, document IDs, transaction codes, specific dates, or requests for a definition from a glossary. They feel like a user is trying to "go to" a location.
#    (...)
#      55
#      56 #             User Query: {query}"""
#      58 prompt1= f"""You are an expert query analysis and keyword extraction bot. Your task is to perform two actions based on a user's query:
#      59
#      60             1.  **Classify the query type**:
#    (...)
#      89
#      90             User Query: {query}"""
# ---> 93 response1 = llm_model.invoke(prompt1)
#      95 llm_check = response1.content
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:372, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)
#     367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
# --> 372         self.generate_prompt(
#     373             [self._convert_input(input)],
#     374             stop=stop,
#     375             callbacks=config.get("callbacks"),
#     376             tags=config.get("tags"),
#     377             metadata=config.get("metadata"),
#     378             run_name=config.get("run_name"),
#     379             run_id=config.pop("run_id", None),
#     380             **kwargs,
#     381         ).generations[0][0],
#     382     ).message
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:957, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     948 @override
#     949 def generate_prompt(
#     950     self,
#    (...)
#     954     **kwargs: Any,
#     955 ) -> LLMResult:
#     956     prompt_messages = [p.to_messages() for p in prompts]
# --> 957     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:776, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     773 for i, m in enumerate(input_messages):
#     774     try:
#     775         results.append(
# --> 776             self._generate_with_cache(
#     777                 m,
#     778                 stop=stop,
#     779                 run_manager=run_managers[i] if run_managers else None,
#     780                 **kwargs,
#     781             )
#     782         )
#     783     except BaseException as e:
#     784         if run_managers:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:1022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1020     result = generate_from_stream(iter(chunks))
#    1021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1022     result = self._generate(
#    1023         messages, stop=stop, run_manager=run_manager, **kwargs
#    1024     )
#    1025 else:
#    1026     result = self._generate(messages, stop=stop, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/langchain_google_genai/chat_models.py:961, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#     935 def _generate(
#     936     self,
#     937     messages: List[BaseMessage],
#    (...)
#     948     **kwargs: Any,
#     949 ) -> ChatResult:
#     950     request = self._prepare_request(
#     951         messages,
#     952         stop=stop,
#    (...)
#     959         tool_choice=tool_choice,
#     960     )
# --> 961     response: GenerateContentResponse = _chat_with_retry(
#     962         request=request,
#     963         **kwargs,
#     964         generation_method=self.client.generate_content,
#     965         metadata=self.default_metadata,
#     966     )
#     967     return _response_to_result(response)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/langchain_google_genai/chat_models.py:196, in _chat_with_retry(generation_method, **kwargs)
#     193     except Exception as e:
#     194         raise e
# --> 196 return _chat_with_retry(**kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/tenacity/__init__.py:338, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     336 copy = self.copy()
#     337 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 338 return copy(f, *args, **kw)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/tenacity/__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/tenacity/__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File /opt/homebrew/anaconda3/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/homebrew/anaconda3/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/langchain_google_genai/chat_models.py:194, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     190     raise ChatGoogleGenerativeAIError(
#     191         f"Invalid argument provided to Gemini: {e}"
#     192     ) from e
#     193 except Exception as e:
# --> 194     raise e
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/langchain_google_genai/chat_models.py:178, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     175 @retry_decorator
#     176 def _chat_with_retry(**kwargs: Any) -> Any:
#     177     try:
# --> 178         return generation_method(**kwargs)
#     179     # Do not retry for these errors.
#     180     except google.api_core.exceptions.FailedPrecondition as exc:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     152 # pylint: disable=broad-except
#     153 # This function explicitly must deal with broad exceptions.
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#     167     time.sleep(next_sleep)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     208 if not predicate_fn(exc):
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#     216     on_error_fn(exc)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/google/api_core/timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# PermissionDenied: 403 Request had insufficient authentication scopes. [reason: "ACCESS_TOKEN_SCOPE_INSUFFICIENT"
# domain: "googleapis.com"
# metadata {
#   key: "method"
#   value: "google.ai.generativelanguage.v1beta.GenerativeService.GenerateContent"
# }
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# ]

# %%
doc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 doc
#
# NameError: name 'doc' is not defined

# %%
##Here I have combined all the previous steps in a single cell block of code
import langchain
from langchain_community.document_loaders import TextLoader, UnstructuredWordDocumentLoader
import fitz
from PIL import Image
import io
import pytesseract
from langchain.docstore.document import Document 
import dotenv
from dotenv import load_dotenv
import os
import asyncio
import shutil
import chromadb
from langchain_community.vectorstores import Chroma
from langchain_text_splitters import RecursiveCharacterTextSplitter, CharacterTextSplitter
# from langchain_openai import OpenAIEmbeddings
import google.generativeai as genai
from langchain_community.embeddings import HuggingFaceEmbeddings 
from langchain_openai import ChatOpenAI

load_dotenv()



# openai_api_key = os.getenv("OPENAI_API_KEY")


def get_file_type_safely(file_path):
    _ , extension = os.path.splitext(file_path)
    return extension.lower()

input_file_path = "/Users/aagambandi/Desktop/MARS_project/ashtang (2).txt"

file_type = get_file_type_safely(input_file_path)

if file_type ==".docx":
    print("The given file is a docx file so no OCR required and text can be directly extracted.")
elif file_type ==".txt":
    print("The given file is a .txt file so no OCR required and text can be directly extracted.")
else:
    print("The given file is a .pdf file and may require OCR.")

if file_type ==".txt":
    loader = TextLoader(input_file_path)
    documents = loader.load()
elif file_type ==".docx" or file_type==".doc":
    loader = UnstructuredWordDocumentLoader(input_file_path)
    documents = loader.load()
else:
    ##Document is in pdf format and may require OCR
    document = fitz.open(input_file_path)
    all_pages_text = []

    for page_num in range(len(document)):
        page = document.load_page(page_num)
        page_text = page.get_text()
        
        # 2. Get all images on the page
        image_list = page.get_images(full=True)
        
        # 3. If images are found, perform OCR on them
        if image_list:
            print(f"Page No.{page_num + 1}: Found {len(image_list)} image(s). Performing targeted OCR.")
            for img_index, img in enumerate(image_list):
                xref = img[0]
                base_image = document.extract_image(xref)
                image_bytes = base_image["image"]
            
                image = Image.open(io.BytesIO(image_bytes))
                ocr_text = pytesseract.image_to_string(image)
        
                page_text += "\n" + ocr_text
        else:
             print(f"Page No.{page_num + 1}: No images found. Direct extraction only.")

        all_pages_text.append(page_text)
        
    document.close()
    full_pdf_text = "\n\n".join(all_pages_text)
    documents = [Document(page_content=full_pdf_text, metadata={"source": input_file_path})]

content = documents[0].page_content
word_list = content.split()
word_count = len(word_list)

llm_model = ChatOpenAI(model = "gpt-4o")

text_splitter = CharacterTextSplitter(chunk_size = 1250, chunk_overlap=250, separator = "------------------------------------------------")
docs = text_splitter.split_documents(documents)


async def summarize_chunk_with_sdk(model, chunk_text, chunk_number, semaphore):
    async with semaphore:
        print(f"  -> Starting API call for chunk {chunk_number}...")
        
        prompt = f"You have been given the following excerpt of text:\n\n---{chunk_text}\n---. In the output just give which chapter or verse of which sthana is given in the text. For eg. if the text contains data of chapter 1 verse 1 of sutra sthana and chapter 1 verse 2 of sutra sthana the output should day chapter 1 verse1 sutra sthana, chapter 1 verse 2 sutra sthana. Make sure to mention which chapter or verse is given in the text."
        # print(prompt)
        response = await model.ainvoke(prompt)
        print(f"  <- Success on chunk {chunk_number}.")
        return response.content.strip()

llm_model_async = ChatOpenAI(model = "gpt-4o")
concurrency_limit = 50
semaphore = asyncio.Semaphore(concurrency_limit)

tasks = []
for i, chunk in enumerate(docs):
    task = summarize_chunk_with_sdk(llm_model_async, chunk.page_content, i + 1, semaphore)
    
    tasks.append(task)
    
summaries = await asyncio.gather(*tasks)

combined_summaries = "\n".join(summaries)




final_prompt = f"""
You are given a sequence of summaries derived from different sections of a text. Based on the combined summary below, extract and return a structured count of chapters and the number of verses in each chapter, categorized by *Sthana* (section).

Format the output as a Python dictionary in the following structure:
{{"sutra sthana": {{1: 43, 2: 23}}, "chikitsa sthana": {{1: 23, 2: 34}}, ...}}

Here is the combined summary:
{combined_summaries}
"""


metadata_response = llm_model.invoke(final_prompt)

metadata = metadata_response.content

print(metadata)
# Out:
# The given file is a .txt file so no OCR required and text can be directly extracted.
#   -> Starting API call for chunk 1...
#   -> Starting API call for chunk 2...
#   -> Starting API call for chunk 3...
#   -> Starting API call for chunk 4...
#   -> Starting API call for chunk 5...
#   -> Starting API call for chunk 6...
#   -> Starting API call for chunk 7...
#   -> Starting API call for chunk 8...
#   -> Starting API call for chunk 9...
#   -> Starting API call for chunk 10...
#   -> Starting API call for chunk 11...
#   -> Starting API call for chunk 12...
#   -> Starting API call for chunk 13...
#   -> Starting API call for chunk 14...
#   -> Starting API call for chunk 15...
#   -> Starting API call for chunk 16...
#   -> Starting API call for chunk 17...
#   -> Starting API call for chunk 18...
#   -> Starting API call for chunk 19...
#   -> Starting API call for chunk 20...
#   -> Starting API call for chunk 21...
#   -> Starting API call for chunk 22...
#   -> Starting API call for chunk 23...
#   -> Starting API call for chunk 24...
#   -> Starting API call for chunk 25...
#   -> Starting API call for chunk 26...
#   -> Starting API call for chunk 27...
#   -> Starting API call for chunk 28...
#   -> Starting API call for chunk 29...
#   -> Starting API call for chunk 30...
#   -> Starting API call for chunk 31...
#   -> Starting API call for chunk 32...
#   -> Starting API call for chunk 33...
#   -> Starting API call for chunk 34...
#   -> Starting API call for chunk 35...
#   -> Starting API call for chunk 36...
#   -> Starting API call for chunk 37...
#   -> Starting API call for chunk 38...
#   -> Starting API call for chunk 39...
#   -> Starting API call for chunk 40...
#   -> Starting API call for chunk 41...
#   -> Starting API call for chunk 42...
#   -> Starting API call for chunk 43...
#   -> Starting API call for chunk 44...
#   -> Starting API call for chunk 45...
#   -> Starting API call for chunk 46...
#   -> Starting API call for chunk 47...
#   -> Starting API call for chunk 48...
#   -> Starting API call for chunk 49...
#   -> Starting API call for chunk 50...
#   <- Success on chunk 35.
#   -> Starting API call for chunk 51...
#   <- Success on chunk 44.
#   -> Starting API call for chunk 52...
#   <- Success on chunk 31.
#   -> Starting API call for chunk 53...
#   <- Success on chunk 28.
#   -> Starting API call for chunk 54...
#   <- Success on chunk 4.
#   -> Starting API call for chunk 55...
#   <- Success on chunk 33.
#   -> Starting API call for chunk 56...
#   <- Success on chunk 15.
#   -> Starting API call for chunk 57...
#   <- Success on chunk 12.
#   -> Starting API call for chunk 58...
#   <- Success on chunk 1.
#   -> Starting API call for chunk 59...
#   <- Success on chunk 2.
#   -> Starting API call for chunk 60...
#   <- Success on chunk 7.
#   -> Starting API call for chunk 61...
#   <- Success on chunk 48.
#   -> Starting API call for chunk 62...
#   <- Success on chunk 43.
#   -> Starting API call for chunk 63...
#   <- Success on chunk 32.
#   -> Starting API call for chunk 64...
#   <- Success on chunk 14.
#   -> Starting API call for chunk 65...
#   <- Success on chunk 5.
#   -> Starting API call for chunk 66...
#   <- Success on chunk 21.
#   -> Starting API call for chunk 67...
#   <- Success on chunk 19.
#   -> Starting API call for chunk 68...
#   <- Success on chunk 49.
#   -> Starting API call for chunk 69...
#   <- Success on chunk 9.
#   -> Starting API call for chunk 70...
#   <- Success on chunk 45.
#   -> Starting API call for chunk 71...
#   <- Success on chunk 34.
#   -> Starting API call for chunk 72...
#   <- Success on chunk 41.
#   -> Starting API call for chunk 73...
#   <- Success on chunk 25.
#   -> Starting API call for chunk 74...
#   <- Success on chunk 6.
#   -> Starting API call for chunk 75...
#   <- Success on chunk 16.
#   -> Starting API call for chunk 76...
#   <- Success on chunk 22.
#   -> Starting API call for chunk 77...
#   <- Success on chunk 50.
#   -> Starting API call for chunk 78...
#   <- Success on chunk 10.
#   -> Starting API call for chunk 79...
#   <- Success on chunk 23.
#   -> Starting API call for chunk 80...
#   <- Success on chunk 18.
#   -> Starting API call for chunk 81...
#   <- Success on chunk 46.
#   -> Starting API call for chunk 82...
#   <- Success on chunk 27.
#   -> Starting API call for chunk 83...
#   <- Success on chunk 37.
#   -> Starting API call for chunk 84...
#   <- Success on chunk 24.
#   -> Starting API call for chunk 85...
#   <- Success on chunk 42.
#   -> Starting API call for chunk 86...
#   <- Success on chunk 13.
#   -> Starting API call for chunk 87...
#   <- Success on chunk 47.
#   -> Starting API call for chunk 88...
#   <- Success on chunk 39.
#   -> Starting API call for chunk 89...
#   <- Success on chunk 3.
#   -> Starting API call for chunk 90...
#   <- Success on chunk 17.
#   -> Starting API call for chunk 91...
#   <- Success on chunk 36.
#   -> Starting API call for chunk 92...
#   <- Success on chunk 26.
#   -> Starting API call for chunk 93...
#   <- Success on chunk 20.
#   -> Starting API call for chunk 94...
#   <- Success on chunk 30.
#   -> Starting API call for chunk 95...
#   <- Success on chunk 8.
#   -> Starting API call for chunk 96...
#   <- Success on chunk 59.
#   -> Starting API call for chunk 97...
#   <- Success on chunk 40.
#   -> Starting API call for chunk 98...
#   <- Success on chunk 51.
#   -> Starting API call for chunk 99...
#   <- Success on chunk 55.
#   -> Starting API call for chunk 100...
#   <- Success on chunk 38.
#   -> Starting API call for chunk 101...
#   <- Success on chunk 54.
#   -> Starting API call for chunk 102...
#   <- Success on chunk 73.
#   -> Starting API call for chunk 103...
#   <- Success on chunk 63.
#   -> Starting API call for chunk 104...
#   <- Success on chunk 66.
#   -> Starting API call for chunk 105...
#   <- Success on chunk 61.
#   -> Starting API call for chunk 106...
#   <- Success on chunk 57.
#   -> Starting API call for chunk 107...
#   <- Success on chunk 85.
#   -> Starting API call for chunk 108...
#   <- Success on chunk 69.
#   -> Starting API call for chunk 109...
#   <- Success on chunk 80.
#   -> Starting API call for chunk 110...
#   <- Success on chunk 74.
#   -> Starting API call for chunk 111...
#   <- Success on chunk 64.
#   -> Starting API call for chunk 112...
#   <- Success on chunk 11.
#   -> Starting API call for chunk 113...
#   <- Success on chunk 67.
#   -> Starting API call for chunk 114...
#   <- Success on chunk 72.
#   -> Starting API call for chunk 115...
#   <- Success on chunk 76.
#   -> Starting API call for chunk 116...
#   <- Success on chunk 78.
#   -> Starting API call for chunk 117...
#   <- Success on chunk 81.
#   -> Starting API call for chunk 118...
#   <- Success on chunk 84.
#   -> Starting API call for chunk 119...
#   <- Success on chunk 77.
#   -> Starting API call for chunk 120...
#   <- Success on chunk 83.
#   -> Starting API call for chunk 121...
#   <- Success on chunk 65.
#   -> Starting API call for chunk 122...
#   <- Success on chunk 70.
#   -> Starting API call for chunk 123...
#   <- Success on chunk 88.
#   -> Starting API call for chunk 124...
#   <- Success on chunk 96.
#   -> Starting API call for chunk 125...
#   <- Success on chunk 62.
#   -> Starting API call for chunk 126...
#   <- Success on chunk 79.
#   -> Starting API call for chunk 127...
#   <- Success on chunk 89.
#   -> Starting API call for chunk 128...
#   <- Success on chunk 71.
#   -> Starting API call for chunk 129...
#   <- Success on chunk 56.
#   -> Starting API call for chunk 130...
#   <- Success on chunk 75.
#   -> Starting API call for chunk 131...
#   <- Success on chunk 98.
#   -> Starting API call for chunk 132...
#   <- Success on chunk 92.
#   -> Starting API call for chunk 133...
#   <- Success on chunk 97.
#   -> Starting API call for chunk 134...
#   <- Success on chunk 87.
#   -> Starting API call for chunk 135...
#   <- Success on chunk 53.
#   -> Starting API call for chunk 136...
#   <- Success on chunk 99.
#   -> Starting API call for chunk 137...
#   <- Success on chunk 103.
#   -> Starting API call for chunk 138...
#   <- Success on chunk 100.
#   -> Starting API call for chunk 139...
#   <- Success on chunk 94.
#   -> Starting API call for chunk 140...
#   <- Success on chunk 52.
#   -> Starting API call for chunk 141...
#   <- Success on chunk 90.
#   -> Starting API call for chunk 142...
#   <- Success on chunk 107.
#   -> Starting API call for chunk 143...
#   <- Success on chunk 82.
#   -> Starting API call for chunk 144...
#   <- Success on chunk 95.
#   -> Starting API call for chunk 145...
#   <- Success on chunk 93.
#   -> Starting API call for chunk 146...
#   <- Success on chunk 60.
#   -> Starting API call for chunk 147...
#   <- Success on chunk 68.
#   -> Starting API call for chunk 148...
#   <- Success on chunk 105.
#   -> Starting API call for chunk 149...
#   <- Success on chunk 104.
#   -> Starting API call for chunk 150...
#   <- Success on chunk 108.
#   -> Starting API call for chunk 151...
#   <- Success on chunk 101.
#   -> Starting API call for chunk 152...
#   <- Success on chunk 86.
#   -> Starting API call for chunk 153...
#   <- Success on chunk 110.
#   -> Starting API call for chunk 154...
#   <- Success on chunk 115.
#   -> Starting API call for chunk 155...
#   <- Success on chunk 109.
#   -> Starting API call for chunk 156...
#   <- Success on chunk 102.
#   -> Starting API call for chunk 157...
#   <- Success on chunk 117.
#   -> Starting API call for chunk 158...
#   <- Success on chunk 120.
#   -> Starting API call for chunk 159...
#   <- Success on chunk 111.
#   -> Starting API call for chunk 160...
#   <- Success on chunk 127.
#   -> Starting API call for chunk 161...
#   <- Success on chunk 116.
#   -> Starting API call for chunk 162...
#   <- Success on chunk 106.
#   -> Starting API call for chunk 163...
#   <- Success on chunk 112.
#   -> Starting API call for chunk 164...
#   <- Success on chunk 123.
#   -> Starting API call for chunk 165...
#   <- Success on chunk 131.
#   -> Starting API call for chunk 166...
#   <- Success on chunk 29.
#   -> Starting API call for chunk 167...
#   <- Success on chunk 119.
#   -> Starting API call for chunk 168...
#   <- Success on chunk 128.
#   -> Starting API call for chunk 169...
#   <- Success on chunk 125.
#   -> Starting API call for chunk 170...
#   <- Success on chunk 132.
#   -> Starting API call for chunk 171...
#   <- Success on chunk 121.
#   -> Starting API call for chunk 172...
#   <- Success on chunk 130.
#   -> Starting API call for chunk 173...
#   <- Success on chunk 118.
#   -> Starting API call for chunk 174...
#   <- Success on chunk 136.
#   -> Starting API call for chunk 175...
#   <- Success on chunk 113.
#   -> Starting API call for chunk 176...
#   <- Success on chunk 133.
#   -> Starting API call for chunk 177...
#   <- Success on chunk 126.
#   -> Starting API call for chunk 178...
#   <- Success on chunk 139.
#   -> Starting API call for chunk 179...
#   <- Success on chunk 143.
#   -> Starting API call for chunk 180...
#   <- Success on chunk 134.
#   -> Starting API call for chunk 181...
#   <- Success on chunk 138.
#   -> Starting API call for chunk 182...
#   <- Success on chunk 141.
#   -> Starting API call for chunk 183...
#   <- Success on chunk 145.
#   -> Starting API call for chunk 184...
#   <- Success on chunk 146.
#   -> Starting API call for chunk 185...
#   <- Success on chunk 114.
#   -> Starting API call for chunk 186...
#   <- Success on chunk 122.
#   -> Starting API call for chunk 187...
#   <- Success on chunk 152.
#   -> Starting API call for chunk 188...
#   <- Success on chunk 124.
#   -> Starting API call for chunk 189...
#   <- Success on chunk 91.
#   -> Starting API call for chunk 190...
#   <- Success on chunk 148.
#   -> Starting API call for chunk 191...
#   <- Success on chunk 158.
#   -> Starting API call for chunk 192...
#   <- Success on chunk 163.
#   -> Starting API call for chunk 193...
#   <- Success on chunk 168.
#   -> Starting API call for chunk 194...
#   <- Success on chunk 160.
#   -> Starting API call for chunk 195...
#   <- Success on chunk 129.
#   -> Starting API call for chunk 196...
#   <- Success on chunk 154.
#   -> Starting API call for chunk 197...
#   <- Success on chunk 144.
#   -> Starting API call for chunk 198...
#   <- Success on chunk 151.
#   -> Starting API call for chunk 199...
#   <- Success on chunk 150.
#   -> Starting API call for chunk 200...
#   <- Success on chunk 159.
#   -> Starting API call for chunk 201...
#   <- Success on chunk 147.
#   -> Starting API call for chunk 202...
#   <- Success on chunk 161.
#   -> Starting API call for chunk 203...
#   <- Success on chunk 135.
#   -> Starting API call for chunk 204...
#   <- Success on chunk 153.
#   -> Starting API call for chunk 205...
#   <- Success on chunk 177.
#   -> Starting API call for chunk 206...
#   <- Success on chunk 164.
#   -> Starting API call for chunk 207...
#   <- Success on chunk 166.
#   -> Starting API call for chunk 208...
#   <- Success on chunk 149.
#   -> Starting API call for chunk 209...
#   <- Success on chunk 165.
#   -> Starting API call for chunk 210...
#   <- Success on chunk 137.
#   -> Starting API call for chunk 211...
#   <- Success on chunk 167.
#   -> Starting API call for chunk 212...
#   <- Success on chunk 179.
#   -> Starting API call for chunk 213...
#   <- Success on chunk 140.
#   -> Starting API call for chunk 214...
#   <- Success on chunk 172.
#   -> Starting API call for chunk 215...
#   <- Success on chunk 175.
#   -> Starting API call for chunk 216...
#   <- Success on chunk 174.
#   -> Starting API call for chunk 217...
#   <- Success on chunk 180.
#   -> Starting API call for chunk 218...
#   <- Success on chunk 156.
#   -> Starting API call for chunk 219...
#   <- Success on chunk 170.
#   -> Starting API call for chunk 220...
#   <- Success on chunk 176.
#   -> Starting API call for chunk 221...
#   <- Success on chunk 155.
#   -> Starting API call for chunk 222...
#   <- Success on chunk 194.
#   -> Starting API call for chunk 223...
#   <- Success on chunk 142.
#   -> Starting API call for chunk 224...
#   <- Success on chunk 157.
#   -> Starting API call for chunk 225...
#   <- Success on chunk 173.
#   -> Starting API call for chunk 226...
#   <- Success on chunk 184.
#   -> Starting API call for chunk 227...
#   <- Success on chunk 183.
#   -> Starting API call for chunk 228...
#   <- Success on chunk 162.
#   -> Starting API call for chunk 229...
#   <- Success on chunk 187.
#   -> Starting API call for chunk 230...
#   <- Success on chunk 189.
#   -> Starting API call for chunk 231...
#   <- Success on chunk 191.
#   -> Starting API call for chunk 232...
#   <- Success on chunk 169.
#   -> Starting API call for chunk 233...
#   <- Success on chunk 185.
#   -> Starting API call for chunk 234...
#   <- Success on chunk 203.
#   -> Starting API call for chunk 235...
#   <- Success on chunk 186.
#   -> Starting API call for chunk 236...
#   <- Success on chunk 197.
#   -> Starting API call for chunk 237...
#   <- Success on chunk 200.
#   -> Starting API call for chunk 238...
#   <- Success on chunk 204.
#   -> Starting API call for chunk 239...
#   <- Success on chunk 199.
#   -> Starting API call for chunk 240...
#   <- Success on chunk 201.
#   -> Starting API call for chunk 241...
#   <- Success on chunk 58.
#   -> Starting API call for chunk 242...
#   <- Success on chunk 196.
#   -> Starting API call for chunk 243...
#   <- Success on chunk 195.
#   -> Starting API call for chunk 244...
#   <- Success on chunk 214.
#   -> Starting API call for chunk 245...
#   <- Success on chunk 205.
#   -> Starting API call for chunk 246...
#   <- Success on chunk 208.
#   -> Starting API call for chunk 247...
#   <- Success on chunk 188.
#   -> Starting API call for chunk 248...
#   <- Success on chunk 181.
#   -> Starting API call for chunk 249...
#   <- Success on chunk 193.
#   -> Starting API call for chunk 250...
#   <- Success on chunk 198.
#   -> Starting API call for chunk 251...
#   <- Success on chunk 209.
#   -> Starting API call for chunk 252...
#   <- Success on chunk 192.
#   -> Starting API call for chunk 253...
#   <- Success on chunk 212.
#   -> Starting API call for chunk 254...
#   <- Success on chunk 171.
#   -> Starting API call for chunk 255...
#   <- Success on chunk 226.
#   -> Starting API call for chunk 256...
#   <- Success on chunk 229.
#   -> Starting API call for chunk 257...
#   <- Success on chunk 206.
#   -> Starting API call for chunk 258...
#   <- Success on chunk 182.
#   -> Starting API call for chunk 259...
#   <- Success on chunk 227.
#   -> Starting API call for chunk 260...
#   <- Success on chunk 211.
#   -> Starting API call for chunk 261...
#   <- Success on chunk 215.
#   -> Starting API call for chunk 262...
#   <- Success on chunk 220.
#   -> Starting API call for chunk 263...
#   <- Success on chunk 178.
#   -> Starting API call for chunk 264...
#   <- Success on chunk 213.
#   -> Starting API call for chunk 265...
#   <- Success on chunk 223.
#   -> Starting API call for chunk 266...
#   <- Success on chunk 218.
#   -> Starting API call for chunk 267...
#   <- Success on chunk 222.
#   -> Starting API call for chunk 268...
#   <- Success on chunk 230.
#   -> Starting API call for chunk 269...
#   <- Success on chunk 207.
#   -> Starting API call for chunk 270...
#   <- Success on chunk 216.
#   -> Starting API call for chunk 271...
#   <- Success on chunk 210.
#   -> Starting API call for chunk 272...
#   <- Success on chunk 248.
#   -> Starting API call for chunk 273...
#   <- Success on chunk 217.
#   -> Starting API call for chunk 274...
#   <- Success on chunk 190.
#   -> Starting API call for chunk 275...
#   <- Success on chunk 237.
#   -> Starting API call for chunk 276...
#   <- Success on chunk 228.
#   -> Starting API call for chunk 277...
#   <- Success on chunk 232.
#   -> Starting API call for chunk 278...
#   <- Success on chunk 241.
#   -> Starting API call for chunk 279...
#   <- Success on chunk 238.
#   -> Starting API call for chunk 280...
#   <- Success on chunk 231.
#   -> Starting API call for chunk 281...
#   <- Success on chunk 234.
#   -> Starting API call for chunk 282...
#   <- Success on chunk 239.
#   -> Starting API call for chunk 283...
#   <- Success on chunk 224.
#   -> Starting API call for chunk 284...
#   <- Success on chunk 253.
#   -> Starting API call for chunk 285...
#   <- Success on chunk 225.
#   -> Starting API call for chunk 286...
#   <- Success on chunk 244.
#   -> Starting API call for chunk 287...
#   <- Success on chunk 221.
#   -> Starting API call for chunk 288...
#   <- Success on chunk 245.
#   -> Starting API call for chunk 289...
#   <- Success on chunk 242.
#   -> Starting API call for chunk 290...
#   <- Success on chunk 247.
#   -> Starting API call for chunk 291...
#   <- Success on chunk 219.
#   -> Starting API call for chunk 292...
#   <- Success on chunk 240.
#   -> Starting API call for chunk 293...
#   <- Success on chunk 233.
#   -> Starting API call for chunk 294...
#   <- Success on chunk 251.
#   -> Starting API call for chunk 295...
#   <- Success on chunk 246.
#   -> Starting API call for chunk 296...
#   <- Success on chunk 254.
#   -> Starting API call for chunk 297...
#   <- Success on chunk 236.
#   -> Starting API call for chunk 298...
#   <- Success on chunk 252.
#   -> Starting API call for chunk 299...
#   <- Success on chunk 265.
#   -> Starting API call for chunk 300...
#   <- Success on chunk 243.
#   -> Starting API call for chunk 301...
#   <- Success on chunk 271.
#   -> Starting API call for chunk 302...
#   <- Success on chunk 202.
#   -> Starting API call for chunk 303...
#   <- Success on chunk 259.
#   -> Starting API call for chunk 304...
#   <- Success on chunk 262.
#   -> Starting API call for chunk 305...
#   <- Success on chunk 256.
#   -> Starting API call for chunk 306...
#   <- Success on chunk 264.
#   -> Starting API call for chunk 307...
#   <- Success on chunk 270.
#   -> Starting API call for chunk 308...
#   <- Success on chunk 255.
#   -> Starting API call for chunk 309...
#   <- Success on chunk 261.
#   -> Starting API call for chunk 310...
#   <- Success on chunk 276.
#   -> Starting API call for chunk 311...
#   <- Success on chunk 266.
#   -> Starting API call for chunk 312...
#   <- Success on chunk 249.
#   -> Starting API call for chunk 313...
#   <- Success on chunk 263.
#   -> Starting API call for chunk 314...
#   <- Success on chunk 277.
#   -> Starting API call for chunk 315...
#   <- Success on chunk 250.
#   -> Starting API call for chunk 316...
#   <- Success on chunk 273.
#   -> Starting API call for chunk 317...
#   <- Success on chunk 283.
#   -> Starting API call for chunk 318...
#   <- Success on chunk 268.
#   -> Starting API call for chunk 319...
#   <- Success on chunk 269.
#   -> Starting API call for chunk 320...
#   <- Success on chunk 257.
#   -> Starting API call for chunk 321...
#   <- Success on chunk 282.
#   -> Starting API call for chunk 322...
#   <- Success on chunk 260.
#   -> Starting API call for chunk 323...
#   <- Success on chunk 258.
#   -> Starting API call for chunk 324...
#   <- Success on chunk 288.
#   -> Starting API call for chunk 325...
#   <- Success on chunk 275.
#   -> Starting API call for chunk 326...
#   <- Success on chunk 267.
#   -> Starting API call for chunk 327...
#   <- Success on chunk 293.
#   -> Starting API call for chunk 328...
#   <- Success on chunk 278.
#   -> Starting API call for chunk 329...
#   <- Success on chunk 274.
#   -> Starting API call for chunk 330...
#   <- Success on chunk 280.
#   -> Starting API call for chunk 331...
#   <- Success on chunk 281.
#   -> Starting API call for chunk 332...
#   <- Success on chunk 292.
#   -> Starting API call for chunk 333...
#   <- Success on chunk 284.
#   -> Starting API call for chunk 334...
#   <- Success on chunk 272.
#   -> Starting API call for chunk 335...
#   <- Success on chunk 279.
#   -> Starting API call for chunk 336...
#   <- Success on chunk 285.
#   -> Starting API call for chunk 337...
#   <- Success on chunk 291.
#   -> Starting API call for chunk 338...
#   <- Success on chunk 286.
#   -> Starting API call for chunk 339...
#   <- Success on chunk 289.
#   -> Starting API call for chunk 340...
#   <- Success on chunk 290.
#   -> Starting API call for chunk 341...
#   <- Success on chunk 295.
#   -> Starting API call for chunk 342...
#   <- Success on chunk 300.
#   -> Starting API call for chunk 343...
#   <- Success on chunk 309.
#   -> Starting API call for chunk 344...
#   <- Success on chunk 308.
#   -> Starting API call for chunk 345...
#   <- Success on chunk 306.
#   -> Starting API call for chunk 346...
#   <- Success on chunk 235.
#   -> Starting API call for chunk 347...
#   <- Success on chunk 294.
#   -> Starting API call for chunk 348...
#   <- Success on chunk 287.
#   -> Starting API call for chunk 349...
#   <- Success on chunk 299.
#   -> Starting API call for chunk 350...
#   <- Success on chunk 298.
#   -> Starting API call for chunk 351...
#   <- Success on chunk 304.
#   -> Starting API call for chunk 352...
#   <- Success on chunk 303.
#   -> Starting API call for chunk 353...
#   <- Success on chunk 301.
#   -> Starting API call for chunk 354...
#   <- Success on chunk 305.
#   -> Starting API call for chunk 355...
#   <- Success on chunk 313.
#   -> Starting API call for chunk 356...
#   <- Success on chunk 318.
#   -> Starting API call for chunk 357...
#   <- Success on chunk 312.
#   -> Starting API call for chunk 358...
#   <- Success on chunk 320.
#   -> Starting API call for chunk 359...
#   <- Success on chunk 326.
#   -> Starting API call for chunk 360...
#   <- Success on chunk 324.
#   -> Starting API call for chunk 361...
#   <- Success on chunk 325.
#   -> Starting API call for chunk 362...
#   <- Success on chunk 302.
#   -> Starting API call for chunk 363...
#   <- Success on chunk 330.
#   -> Starting API call for chunk 364...
#   <- Success on chunk 332.
#   -> Starting API call for chunk 365...
#   <- Success on chunk 321.
#   -> Starting API call for chunk 366...
#   <- Success on chunk 329.
#   -> Starting API call for chunk 367...
#   <- Success on chunk 311.
#   -> Starting API call for chunk 368...
#   <- Success on chunk 334.
#   -> Starting API call for chunk 369...
#   <- Success on chunk 339.
#   -> Starting API call for chunk 370...
#   <- Success on chunk 307.
#   -> Starting API call for chunk 371...
#   <- Success on chunk 310.
#   -> Starting API call for chunk 372...
#   <- Success on chunk 345.
#   -> Starting API call for chunk 373...
#   <- Success on chunk 317.
#   -> Starting API call for chunk 374...
#   <- Success on chunk 342.
#   -> Starting API call for chunk 375...
#   <- Success on chunk 340.
#   -> Starting API call for chunk 376...
#   <- Success on chunk 316.
#   -> Starting API call for chunk 377...
#   <- Success on chunk 319.
#   -> Starting API call for chunk 378...
#   <- Success on chunk 315.
#   -> Starting API call for chunk 379...
#   <- Success on chunk 349.
#   -> Starting API call for chunk 380...
#   <- Success on chunk 322.
#   -> Starting API call for chunk 381...
#   <- Success on chunk 352.
#   -> Starting API call for chunk 382...
#   <- Success on chunk 336.
#   -> Starting API call for chunk 383...
#   <- Success on chunk 327.
#   -> Starting API call for chunk 384...
#   <- Success on chunk 333.
#   -> Starting API call for chunk 385...
#   <- Success on chunk 328.
#   -> Starting API call for chunk 386...
#   <- Success on chunk 350.
#   <- Success on chunk 344.
#   -> Starting API call for chunk 387...
#   -> Starting API call for chunk 388...
#   <- Success on chunk 323.
#   -> Starting API call for chunk 389...
#   <- Success on chunk 348.
#   -> Starting API call for chunk 390...
#   <- Success on chunk 297.
#   -> Starting API call for chunk 391...
#   <- Success on chunk 358.
#   -> Starting API call for chunk 392...
#   <- Success on chunk 347.
#   -> Starting API call for chunk 393...
#   <- Success on chunk 343.
#   -> Starting API call for chunk 394...
#   <- Success on chunk 331.
#   -> Starting API call for chunk 395...
#   <- Success on chunk 335.
#   -> Starting API call for chunk 396...
#   <- Success on chunk 353.
#   -> Starting API call for chunk 397...
#   <- Success on chunk 337.
#   -> Starting API call for chunk 398...
#   <- Success on chunk 314.
#   -> Starting API call for chunk 399...
#   <- Success on chunk 357.
#   -> Starting API call for chunk 400...
#   <- Success on chunk 360.
#   -> Starting API call for chunk 401...
#   <- Success on chunk 364.
#   -> Starting API call for chunk 402...
#   <- Success on chunk 351.
#   -> Starting API call for chunk 403...
#   <- Success on chunk 346.
#   -> Starting API call for chunk 404...
#   <- Success on chunk 365.
#   -> Starting API call for chunk 405...
#   <- Success on chunk 372.
#   -> Starting API call for chunk 406...
#   <- Success on chunk 354.
#   -> Starting API call for chunk 407...
#   <- Success on chunk 361.
#   -> Starting API call for chunk 408...
#   <- Success on chunk 356.
#   -> Starting API call for chunk 409...
#   <- Success on chunk 359.
#   -> Starting API call for chunk 410...
#   <- Success on chunk 355.
#   -> Starting API call for chunk 411...
#   <- Success on chunk 362.
#   -> Starting API call for chunk 412...
#   <- Success on chunk 374.
#   -> Starting API call for chunk 413...
#   <- Success on chunk 373.
#   -> Starting API call for chunk 414...
#   <- Success on chunk 383.
#   -> Starting API call for chunk 415...
#   <- Success on chunk 390.
#   -> Starting API call for chunk 416...
#   <- Success on chunk 386.
#   -> Starting API call for chunk 417...
#   <- Success on chunk 387.
#   -> Starting API call for chunk 418...
#   <- Success on chunk 392.
#   -> Starting API call for chunk 419...
#   <- Success on chunk 391.
#   -> Starting API call for chunk 420...
#   <- Success on chunk 366.
#   -> Starting API call for chunk 421...
#   <- Success on chunk 396.
#   -> Starting API call for chunk 422...
#   <- Success on chunk 368.
#   -> Starting API call for chunk 423...
#   <- Success on chunk 377.
#   -> Starting API call for chunk 424...
#   <- Success on chunk 388.
#   -> Starting API call for chunk 425...
#   <- Success on chunk 378.
#   -> Starting API call for chunk 426...
#   <- Success on chunk 367.
#   -> Starting API call for chunk 427...
#   <- Success on chunk 370.
#   -> Starting API call for chunk 428...
#   <- Success on chunk 393.
#   -> Starting API call for chunk 429...
#   <- Success on chunk 395.
#   -> Starting API call for chunk 430...
#   <- Success on chunk 371.
#   -> Starting API call for chunk 431...
#   <- Success on chunk 384.
#   -> Starting API call for chunk 432...
#   <- Success on chunk 376.
#   -> Starting API call for chunk 433...
#   <- Success on chunk 381.
#   -> Starting API call for chunk 434...
#   <- Success on chunk 363.
#   -> Starting API call for chunk 435...
#   <- Success on chunk 403.
#   -> Starting API call for chunk 436...
#   <- Success on chunk 400.
#   -> Starting API call for chunk 437...
#   <- Success on chunk 380.
#   -> Starting API call for chunk 438...
#   <- Success on chunk 402.
#   -> Starting API call for chunk 439...
#   <- Success on chunk 394.
#   -> Starting API call for chunk 440...
#   <- Success on chunk 379.
#   -> Starting API call for chunk 441...
#   <- Success on chunk 404.
#   -> Starting API call for chunk 442...
#   <- Success on chunk 412.
#   -> Starting API call for chunk 443...
#   <- Success on chunk 408.
#   -> Starting API call for chunk 444...
#   <- Success on chunk 389.
#   -> Starting API call for chunk 445...
#   <- Success on chunk 413.
#   -> Starting API call for chunk 446...
#   <- Success on chunk 401.
#   -> Starting API call for chunk 447...
#   <- Success on chunk 411.
#   -> Starting API call for chunk 448...
#   <- Success on chunk 399.
#   -> Starting API call for chunk 449...
#   <- Success on chunk 414.
#   -> Starting API call for chunk 450...
#   <- Success on chunk 382.
#   -> Starting API call for chunk 451...
#   <- Success on chunk 418.
#   -> Starting API call for chunk 452...
#   <- Success on chunk 410.
#   -> Starting API call for chunk 453...
#   <- Success on chunk 406.
#   -> Starting API call for chunk 454...
#   <- Success on chunk 405.
#   -> Starting API call for chunk 455...
#   <- Success on chunk 407.
#   -> Starting API call for chunk 456...
#   <- Success on chunk 424.
#   -> Starting API call for chunk 457...
#   <- Success on chunk 432.
#   -> Starting API call for chunk 458...
#   <- Success on chunk 409.
#   -> Starting API call for chunk 459...
#   <- Success on chunk 431.
#   -> Starting API call for chunk 460...
#   <- Success on chunk 420.
#   -> Starting API call for chunk 461...
#   <- Success on chunk 397.
#   -> Starting API call for chunk 462...
#   <- Success on chunk 369.
#   -> Starting API call for chunk 463...
#   <- Success on chunk 398.
#   -> Starting API call for chunk 464...
#   <- Success on chunk 428.
#   -> Starting API call for chunk 465...
#   <- Success on chunk 415.
#   -> Starting API call for chunk 466...
#   <- Success on chunk 416.
#   -> Starting API call for chunk 467...
#   <- Success on chunk 435.
#   -> Starting API call for chunk 468...
#   <- Success on chunk 426.
#   -> Starting API call for chunk 469...
#   <- Success on chunk 433.
#   -> Starting API call for chunk 470...
#   <- Success on chunk 429.
#   -> Starting API call for chunk 471...
#   <- Success on chunk 417.
#   -> Starting API call for chunk 472...
#   <- Success on chunk 422.
#   -> Starting API call for chunk 473...
#   <- Success on chunk 421.
#   -> Starting API call for chunk 474...
#   <- Success on chunk 385.
#   -> Starting API call for chunk 475...
#   <- Success on chunk 436.
#   -> Starting API call for chunk 476...
#   <- Success on chunk 438.
#   -> Starting API call for chunk 477...
#   <- Success on chunk 427.
#   -> Starting API call for chunk 478...
#   <- Success on chunk 434.
#   -> Starting API call for chunk 479...
#   <- Success on chunk 430.
#   -> Starting API call for chunk 480...
#   <- Success on chunk 440.
#   -> Starting API call for chunk 481...
#   <- Success on chunk 443.
#   -> Starting API call for chunk 482...
#   <- Success on chunk 437.
#   -> Starting API call for chunk 483...
#   <- Success on chunk 444.
#   -> Starting API call for chunk 484...
#   <- Success on chunk 446.
#   -> Starting API call for chunk 485...
#   <- Success on chunk 423.
#   -> Starting API call for chunk 486...
#   <- Success on chunk 456.
#   -> Starting API call for chunk 487...
#   <- Success on chunk 453.
#   -> Starting API call for chunk 488...
#   <- Success on chunk 452.
#   <- Success on chunk 459.
#   -> Starting API call for chunk 489...
#   -> Starting API call for chunk 490...
#   <- Success on chunk 455.
#   -> Starting API call for chunk 491...
#   <- Success on chunk 462.
#   -> Starting API call for chunk 492...
#   <- Success on chunk 445.
#   -> Starting API call for chunk 493...
#   <- Success on chunk 454.
#   -> Starting API call for chunk 494...
#   <- Success on chunk 465.
#   -> Starting API call for chunk 495...
#   <- Success on chunk 464.
#   -> Starting API call for chunk 496...
#   <- Success on chunk 439.
#   -> Starting API call for chunk 497...
#   <- Success on chunk 461.
#   -> Starting API call for chunk 498...
#   <- Success on chunk 475.
#   -> Starting API call for chunk 499...
#   <- Success on chunk 441.
#   -> Starting API call for chunk 500...
#   <- Success on chunk 449.
#   -> Starting API call for chunk 501...
#   <- Success on chunk 457.
#   -> Starting API call for chunk 502...
#   <- Success on chunk 458.
#   -> Starting API call for chunk 503...
#   <- Success on chunk 450.
#   -> Starting API call for chunk 504...
#   <- Success on chunk 466.
#   -> Starting API call for chunk 505...
#   <- Success on chunk 451.
#   -> Starting API call for chunk 506...
#   <- Success on chunk 472.
#   -> Starting API call for chunk 507...
#   <- Success on chunk 463.
#   -> Starting API call for chunk 508...
#   <- Success on chunk 470.
#   -> Starting API call for chunk 509...
#   <- Success on chunk 447.
#   -> Starting API call for chunk 510...
#   <- Success on chunk 469.
#   -> Starting API call for chunk 511...
#   <- Success on chunk 296.
#   -> Starting API call for chunk 512...
#   <- Success on chunk 476.
#   -> Starting API call for chunk 513...
#   <- Success on chunk 478.
#   -> Starting API call for chunk 514...
#   <- Success on chunk 448.
#   -> Starting API call for chunk 515...
#   <- Success on chunk 486.
#   -> Starting API call for chunk 516...
#   <- Success on chunk 487.
#   -> Starting API call for chunk 517...
#   <- Success on chunk 484.
#   -> Starting API call for chunk 518...
#   <- Success on chunk 482.
#   -> Starting API call for chunk 519...
#   <- Success on chunk 474.
#   -> Starting API call for chunk 520...
#   <- Success on chunk 492.
#   -> Starting API call for chunk 521...
#   <- Success on chunk 480.
#   -> Starting API call for chunk 522...
#   <- Success on chunk 489.
#   -> Starting API call for chunk 523...
#   <- Success on chunk 477.
#   -> Starting API call for chunk 524...
#   <- Success on chunk 375.
#   -> Starting API call for chunk 525...
#   <- Success on chunk 496.
#   -> Starting API call for chunk 526...
#   <- Success on chunk 488.
#   -> Starting API call for chunk 527...
#   <- Success on chunk 425.
#   -> Starting API call for chunk 528...
#   <- Success on chunk 442.
#   -> Starting API call for chunk 529...
#   <- Success on chunk 483.
#   -> Starting API call for chunk 530...
#   <- Success on chunk 481.
#   -> Starting API call for chunk 531...
#   <- Success on chunk 494.
#   -> Starting API call for chunk 532...
#   <- Success on chunk 498.
#   -> Starting API call for chunk 533...
#   <- Success on chunk 493.
#   -> Starting API call for chunk 534...
#   <- Success on chunk 499.
#   <- Success on chunk 338.
#   -> Starting API call for chunk 535...
#   -> Starting API call for chunk 536...
#   <- Success on chunk 505.
#   -> Starting API call for chunk 537...
#   <- Success on chunk 503.
#   -> Starting API call for chunk 538...
#   <- Success on chunk 341.
#   -> Starting API call for chunk 539...
#   <- Success on chunk 502.
#   -> Starting API call for chunk 540...
#   <- Success on chunk 500.
#   -> Starting API call for chunk 541...
#   <- Success on chunk 460.
#   -> Starting API call for chunk 542...
#   <- Success on chunk 495.
#   -> Starting API call for chunk 543...
#   <- Success on chunk 501.
#   -> Starting API call for chunk 544...
#   <- Success on chunk 509.
#   -> Starting API call for chunk 545...
#   <- Success on chunk 510.
#   -> Starting API call for chunk 546...
#   <- Success on chunk 473.
#   -> Starting API call for chunk 547...
#   <- Success on chunk 471.
#   -> Starting API call for chunk 548...
#   <- Success on chunk 518.
#   -> Starting API call for chunk 549...
#   <- Success on chunk 507.
#   -> Starting API call for chunk 550...
#   <- Success on chunk 512.
#   -> Starting API call for chunk 551...
#   <- Success on chunk 491.
#   -> Starting API call for chunk 552...
#   <- Success on chunk 485.
#   -> Starting API call for chunk 553...
#   <- Success on chunk 504.
#   -> Starting API call for chunk 554...
#   <- Success on chunk 506.
#   -> Starting API call for chunk 555...
#   <- Success on chunk 419.
#   -> Starting API call for chunk 556...
#   <- Success on chunk 520.
#   -> Starting API call for chunk 557...
#   <- Success on chunk 517.
#   -> Starting API call for chunk 558...
#   <- Success on chunk 521.
#   -> Starting API call for chunk 559...
#   <- Success on chunk 519.
#   -> Starting API call for chunk 560...
#   <- Success on chunk 511.
#   -> Starting API call for chunk 561...
#   <- Success on chunk 490.
#   -> Starting API call for chunk 562...
#   <- Success on chunk 513.
#   -> Starting API call for chunk 563...
#   <- Success on chunk 514.
#   -> Starting API call for chunk 564...
#   <- Success on chunk 508.
#   -> Starting API call for chunk 565...
#   <- Success on chunk 525.
#   -> Starting API call for chunk 566...
#   <- Success on chunk 524.
#   -> Starting API call for chunk 567...
#   <- Success on chunk 515.
#   -> Starting API call for chunk 568...
#   <- Success on chunk 527.
#   -> Starting API call for chunk 569...
#   <- Success on chunk 516.
#   -> Starting API call for chunk 570...
#   <- Success on chunk 528.
#   -> Starting API call for chunk 571...
#   <- Success on chunk 529.
#   -> Starting API call for chunk 572...
#   <- Success on chunk 540.
#   -> Starting API call for chunk 573...
#   <- Success on chunk 534.
#   -> Starting API call for chunk 574...
#   <- Success on chunk 532.
#   -> Starting API call for chunk 575...
#   <- Success on chunk 543.
#   -> Starting API call for chunk 576...
#   <- Success on chunk 530.
#   -> Starting API call for chunk 577...
#   <- Success on chunk 542.
#   -> Starting API call for chunk 578...
#   <- Success on chunk 538.
#   -> Starting API call for chunk 579...
#   <- Success on chunk 526.
#   -> Starting API call for chunk 580...
#   <- Success on chunk 553.
#   -> Starting API call for chunk 581...
#   <- Success on chunk 531.
#   -> Starting API call for chunk 582...
#   <- Success on chunk 541.
#   -> Starting API call for chunk 583...
#   <- Success on chunk 533.
#   -> Starting API call for chunk 584...
#   <- Success on chunk 554.
#   -> Starting API call for chunk 585...
#   <- Success on chunk 552.
#   -> Starting API call for chunk 586...
#   <- Success on chunk 537.
#   -> Starting API call for chunk 587...
#   <- Success on chunk 536.
#   -> Starting API call for chunk 588...
#   <- Success on chunk 560.
#   -> Starting API call for chunk 589...
#   <- Success on chunk 557.
#   -> Starting API call for chunk 590...
#   <- Success on chunk 556.
#   -> Starting API call for chunk 591...
#   <- Success on chunk 544.
#   -> Starting API call for chunk 592...
#   <- Success on chunk 558.
#   -> Starting API call for chunk 593...
#   <- Success on chunk 548.
#   -> Starting API call for chunk 594...
#   <- Success on chunk 546.
#   -> Starting API call for chunk 595...
#   <- Success on chunk 549.
#   -> Starting API call for chunk 596...
#   <- Success on chunk 539.
#   -> Starting API call for chunk 597...
#   <- Success on chunk 523.
#   -> Starting API call for chunk 598...
#   <- Success on chunk 562.
#   -> Starting API call for chunk 599...
#   <- Success on chunk 468.
#   -> Starting API call for chunk 600...
#   <- Success on chunk 559.
#   -> Starting API call for chunk 601...
#   <- Success on chunk 467.
#   -> Starting API call for chunk 602...
#   <- Success on chunk 550.
#   -> Starting API call for chunk 603...
#   <- Success on chunk 497.
#   -> Starting API call for chunk 604...
#   <- Success on chunk 479.
#   -> Starting API call for chunk 605...
#   <- Success on chunk 555.
#   -> Starting API call for chunk 606...
#   <- Success on chunk 547.
#   -> Starting API call for chunk 607...
#   <- Success on chunk 561.
#   -> Starting API call for chunk 608...
#   <- Success on chunk 568.
#   -> Starting API call for chunk 609...
#   <- Success on chunk 551.
#   -> Starting API call for chunk 610...
#   <- Success on chunk 522.
#   -> Starting API call for chunk 611...
#   <- Success on chunk 545.
#   -> Starting API call for chunk 612...
#   <- Success on chunk 563.
#   -> Starting API call for chunk 613...
#   <- Success on chunk 564.
#   -> Starting API call for chunk 614...
#   <- Success on chunk 535.
#   -> Starting API call for chunk 615...
#   <- Success on chunk 566.
#   -> Starting API call for chunk 616...
#   <- Success on chunk 567.
#   -> Starting API call for chunk 617...
#   <- Success on chunk 580.
#   -> Starting API call for chunk 618...
#   <- Success on chunk 571.
#   -> Starting API call for chunk 619...
#   <- Success on chunk 582.
#   -> Starting API call for chunk 620...
#   <- Success on chunk 565.
#   -> Starting API call for chunk 621...
#   <- Success on chunk 573.
#   -> Starting API call for chunk 622...
#   <- Success on chunk 585.
#   -> Starting API call for chunk 623...
#   <- Success on chunk 591.
#   -> Starting API call for chunk 624...
#   <- Success on chunk 569.
#   -> Starting API call for chunk 625...
#   <- Success on chunk 577.
#   -> Starting API call for chunk 626...
#   <- Success on chunk 570.
#   -> Starting API call for chunk 627...
#   <- Success on chunk 587.
#   -> Starting API call for chunk 628...
#   <- Success on chunk 578.
#   -> Starting API call for chunk 629...
#   <- Success on chunk 579.
#   -> Starting API call for chunk 630...
#   <- Success on chunk 588.
#   -> Starting API call for chunk 631...
#   <- Success on chunk 575.
#   -> Starting API call for chunk 632...
#   <- Success on chunk 572.
#   -> Starting API call for chunk 633...
#   <- Success on chunk 594.
#   -> Starting API call for chunk 634...
#   <- Success on chunk 584.
#   -> Starting API call for chunk 635...
#   <- Success on chunk 576.
#   -> Starting API call for chunk 636...
#   <- Success on chunk 583.
#   -> Starting API call for chunk 637...
#   <- Success on chunk 602.
#   -> Starting API call for chunk 638...
#   <- Success on chunk 600.
#   -> Starting API call for chunk 639...
#   <- Success on chunk 603.
#   -> Starting API call for chunk 640...
#   <- Success on chunk 574.
#   -> Starting API call for chunk 641...
#   <- Success on chunk 589.
#   -> Starting API call for chunk 642...
#   <- Success on chunk 592.
#   -> Starting API call for chunk 643...
#   <- Success on chunk 599.
#   -> Starting API call for chunk 644...
#   <- Success on chunk 590.
#   -> Starting API call for chunk 645...
#   <- Success on chunk 595.
#   -> Starting API call for chunk 646...
#   <- Success on chunk 596.
#   -> Starting API call for chunk 647...
#   <- Success on chunk 609.
#   -> Starting API call for chunk 648...
#   <- Success on chunk 607.
#   -> Starting API call for chunk 649...
#   <- Success on chunk 615.
#   -> Starting API call for chunk 650...
#   <- Success on chunk 598.
#   -> Starting API call for chunk 651...
#   <- Success on chunk 593.
#   -> Starting API call for chunk 652...
#   <- Success on chunk 610.
#   -> Starting API call for chunk 653...
#   <- Success on chunk 581.
#   -> Starting API call for chunk 654...
#   <- Success on chunk 616.
#   -> Starting API call for chunk 655...
#   <- Success on chunk 608.
#   -> Starting API call for chunk 656...
#   <- Success on chunk 605.
#   -> Starting API call for chunk 657...
#   <- Success on chunk 601.
#   -> Starting API call for chunk 658...
#   <- Success on chunk 606.
#   -> Starting API call for chunk 659...
#   <- Success on chunk 611.
#   -> Starting API call for chunk 660...
#   <- Success on chunk 604.
#   -> Starting API call for chunk 661...
#   <- Success on chunk 628.
#   -> Starting API call for chunk 662...
#   <- Success on chunk 597.
#   -> Starting API call for chunk 663...
#   <- Success on chunk 626.
#   -> Starting API call for chunk 664...
#   <- Success on chunk 625.
#   -> Starting API call for chunk 665...
#   <- Success on chunk 586.
#   -> Starting API call for chunk 666...
#   <- Success on chunk 613.
#   -> Starting API call for chunk 667...
#   <- Success on chunk 619.
#   -> Starting API call for chunk 668...
#   <- Success on chunk 623.
#   -> Starting API call for chunk 669...
#   <- Success on chunk 629.
#   -> Starting API call for chunk 670...
#   <- Success on chunk 624.
#   -> Starting API call for chunk 671...
#   <- Success on chunk 614.
#   -> Starting API call for chunk 672...
#   <- Success on chunk 633.
#   -> Starting API call for chunk 673...
#   <- Success on chunk 618.
#   -> Starting API call for chunk 674...
#   <- Success on chunk 632.
#   -> Starting API call for chunk 675...
#   <- Success on chunk 635.
#   -> Starting API call for chunk 676...
#   <- Success on chunk 631.
#   -> Starting API call for chunk 677...
#   <- Success on chunk 637.
#   -> Starting API call for chunk 678...
#   <- Success on chunk 622.
#   -> Starting API call for chunk 679...
#   <- Success on chunk 639.
#   -> Starting API call for chunk 680...
#   <- Success on chunk 630.
#   -> Starting API call for chunk 681...
#   <- Success on chunk 640.
#   -> Starting API call for chunk 682...
#   <- Success on chunk 627.
#   -> Starting API call for chunk 683...
#   <- Success on chunk 645.
#   -> Starting API call for chunk 684...
#   <- Success on chunk 649.
#   -> Starting API call for chunk 685...
#   <- Success on chunk 634.
#   -> Starting API call for chunk 686...
#   <- Success on chunk 642.
#   -> Starting API call for chunk 687...
#   <- Success on chunk 646.
#   -> Starting API call for chunk 688...
#   <- Success on chunk 641.
#   -> Starting API call for chunk 689...
#   <- Success on chunk 658.
#   -> Starting API call for chunk 690...
#   <- Success on chunk 638.
#   -> Starting API call for chunk 691...
#   <- Success on chunk 655.
#   -> Starting API call for chunk 692...
#   <- Success on chunk 651.
#   -> Starting API call for chunk 693...
#   <- Success on chunk 636.
#   -> Starting API call for chunk 694...
#   <- Success on chunk 620.
#   -> Starting API call for chunk 695...
#   <- Success on chunk 652.
#   -> Starting API call for chunk 696...
#   <- Success on chunk 662.
#   -> Starting API call for chunk 697...
#   <- Success on chunk 654.
#   -> Starting API call for chunk 698...
#   <- Success on chunk 653.
#   -> Starting API call for chunk 699...
#   <- Success on chunk 664.
#   -> Starting API call for chunk 700...
#   <- Success on chunk 665.
#   -> Starting API call for chunk 701...
#   <- Success on chunk 659.
#   -> Starting API call for chunk 702...
#   <- Success on chunk 644.
#   -> Starting API call for chunk 703...
#   <- Success on chunk 660.
#   -> Starting API call for chunk 704...
#   <- Success on chunk 648.
#   -> Starting API call for chunk 705...
#   <- Success on chunk 617.
#   -> Starting API call for chunk 706...
#   <- Success on chunk 667.
#   -> Starting API call for chunk 707...
#   <- Success on chunk 668.
#   -> Starting API call for chunk 708...
#   <- Success on chunk 675.
#   -> Starting API call for chunk 709...
#   <- Success on chunk 670.
#   -> Starting API call for chunk 710...
#   <- Success on chunk 647.
#   -> Starting API call for chunk 711...
#   <- Success on chunk 669.
#   -> Starting API call for chunk 712...
#   <- Success on chunk 674.
#   -> Starting API call for chunk 713...
#   <- Success on chunk 677.
#   -> Starting API call for chunk 714...
#   <- Success on chunk 612.
#   -> Starting API call for chunk 715...
#   <- Success on chunk 666.
#   -> Starting API call for chunk 716...
#   <- Success on chunk 676.
#   -> Starting API call for chunk 717...
#   <- Success on chunk 673.
#   -> Starting API call for chunk 718...
#   <- Success on chunk 671.
#   -> Starting API call for chunk 719...
#   <- Success on chunk 657.
#   -> Starting API call for chunk 720...
#   <- Success on chunk 643.
#   -> Starting API call for chunk 721...
#   <- Success on chunk 681.
#   -> Starting API call for chunk 722...
#   <- Success on chunk 663.
#   -> Starting API call for chunk 723...
#   <- Success on chunk 680.
#   -> Starting API call for chunk 724...
#   <- Success on chunk 678.
#   -> Starting API call for chunk 725...
#   <- Success on chunk 686.
#   -> Starting API call for chunk 726...
#   <- Success on chunk 656.
#   -> Starting API call for chunk 727...
#   <- Success on chunk 682.
#   -> Starting API call for chunk 728...
#   <- Success on chunk 650.
#   -> Starting API call for chunk 729...
#   <- Success on chunk 689.
#   -> Starting API call for chunk 730...
#   <- Success on chunk 687.
#   -> Starting API call for chunk 731...
#   <- Success on chunk 683.
#   -> Starting API call for chunk 732...
#   <- Success on chunk 696.
#   -> Starting API call for chunk 733...
#   <- Success on chunk 695.
#   -> Starting API call for chunk 734...
#   <- Success on chunk 672.
#   -> Starting API call for chunk 735...
#   <- Success on chunk 685.
#   -> Starting API call for chunk 736...
#   <- Success on chunk 688.
#   -> Starting API call for chunk 737...
#   <- Success on chunk 684.
#   -> Starting API call for chunk 738...
#   <- Success on chunk 692.
# ...
#   -> Starting API call for chunk 1309...
#   <- Success on chunk 1260.
#   -> Starting API call for chunk 1310...
#   <- Success on chunk 1271.
#   -> Starting API call for chunk 1311...
#   <- Success on chunk 1270.
#   -> Starting API call for chunk 1312...
#   <- Success on chunk 1289.
#   -> Starting API call for chunk 1313...
#   <- Success on chunk 1256.
#   -> Starting API call for chunk 1314...
#   <- Success on chunk 1279.
#   -> Starting API call for chunk 1315...
#   <- Success on chunk 1277.
#   -> Starting API call for chunk 1316...
#   <- Success on chunk 1278.
#   -> Starting API call for chunk 1317...
#   <- Success on chunk 1267.
#   -> Starting API call for chunk 1318...
#   <- Success on chunk 1273.
#   -> Starting API call for chunk 1319...
#   <- Success on chunk 1272.
#   -> Starting API call for chunk 1320...
#   <- Success on chunk 1282.
#   -> Starting API call for chunk 1321...
#   <- Success on chunk 1275.
#   -> Starting API call for chunk 1322...
#   <- Success on chunk 1268.
#   -> Starting API call for chunk 1323...
#   <- Success on chunk 1269.
#   -> Starting API call for chunk 1324...
#   <- Success on chunk 1280.
#   -> Starting API call for chunk 1325...
#   <- Success on chunk 1255.
#   -> Starting API call for chunk 1326...
#   <- Success on chunk 1265.
#   -> Starting API call for chunk 1327...
#   <- Success on chunk 1281.
#   -> Starting API call for chunk 1328...
#   <- Success on chunk 1293.
#   -> Starting API call for chunk 1329...
#   <- Success on chunk 1262.
#   -> Starting API call for chunk 1330...
#   <- Success on chunk 1286.
#   -> Starting API call for chunk 1331...
#   <- Success on chunk 1240.
#   -> Starting API call for chunk 1332...
#   <- Success on chunk 1274.
#   -> Starting API call for chunk 1333...
#   <- Success on chunk 1283.
#   -> Starting API call for chunk 1334...
#   <- Success on chunk 1284.
#   -> Starting API call for chunk 1335...
#   <- Success on chunk 1285.
#   -> Starting API call for chunk 1336...
#   <- Success on chunk 1291.
#   <- Success on chunk 1297.
#   <- Success on chunk 1308.
#   <- Success on chunk 1292.
#   <- Success on chunk 1296.
#   -> Starting API call for chunk 1337...
#   -> Starting API call for chunk 1338...
#   -> Starting API call for chunk 1339...
#   -> Starting API call for chunk 1340...
#   -> Starting API call for chunk 1341...
#   <- Success on chunk 1288.
#   -> Starting API call for chunk 1342...
#   <- Success on chunk 1295.
#   -> Starting API call for chunk 1343...
#   <- Success on chunk 1276.
#   -> Starting API call for chunk 1344...
#   <- Success on chunk 1294.
#   -> Starting API call for chunk 1345...
#   <- Success on chunk 1306.
#   -> Starting API call for chunk 1346...
#   <- Success on chunk 1305.
#   -> Starting API call for chunk 1347...
#   <- Success on chunk 1304.
#   -> Starting API call for chunk 1348...
#   <- Success on chunk 1302.
#   -> Starting API call for chunk 1349...
#   <- Success on chunk 1290.
#   -> Starting API call for chunk 1350...
#   <- Success on chunk 1309.
#   -> Starting API call for chunk 1351...
#   <- Success on chunk 1300.
#   -> Starting API call for chunk 1352...
#   <- Success on chunk 1299.
#   -> Starting API call for chunk 1353...
#   <- Success on chunk 1319.
#   -> Starting API call for chunk 1354...
#   <- Success on chunk 1314.
#   -> Starting API call for chunk 1355...
#   <- Success on chunk 1313.
#   -> Starting API call for chunk 1356...
#   <- Success on chunk 1311.
#   -> Starting API call for chunk 1357...
#   <- Success on chunk 1320.
#   -> Starting API call for chunk 1358...
#   <- Success on chunk 1310.
#   -> Starting API call for chunk 1359...
#   <- Success on chunk 1318.
#   -> Starting API call for chunk 1360...
#   <- Success on chunk 1322.
#   -> Starting API call for chunk 1361...
#   <- Success on chunk 1327.
#   -> Starting API call for chunk 1362...
#   <- Success on chunk 1324.
#   -> Starting API call for chunk 1363...
#   <- Success on chunk 1298.
#   -> Starting API call for chunk 1364...
#   <- Success on chunk 1323.
#   -> Starting API call for chunk 1365...
#   <- Success on chunk 1328.
#   -> Starting API call for chunk 1366...
#   <- Success on chunk 1303.
#   -> Starting API call for chunk 1367...
#   <- Success on chunk 1315.
#   -> Starting API call for chunk 1368...
#   <- Success on chunk 1329.
#   -> Starting API call for chunk 1369...
#   <- Success on chunk 1335.
#   -> Starting API call for chunk 1370...
#   <- Success on chunk 1330.
#   -> Starting API call for chunk 1371...
#   <- Success on chunk 1325.
#   -> Starting API call for chunk 1372...
#   <- Success on chunk 1321.
#   -> Starting API call for chunk 1373...
#   <- Success on chunk 1199.
#   -> Starting API call for chunk 1374...
#   <- Success on chunk 1337.
#   -> Starting API call for chunk 1375...
#   <- Success on chunk 1333.
#   -> Starting API call for chunk 1376...
#   <- Success on chunk 1331.
#   -> Starting API call for chunk 1377...
#   <- Success on chunk 1316.
#   -> Starting API call for chunk 1378...
#   <- Success on chunk 1334.
#   -> Starting API call for chunk 1379...
#   <- Success on chunk 1342.
#   -> Starting API call for chunk 1380...
#   <- Success on chunk 1332.
#   -> Starting API call for chunk 1381...
#   <- Success on chunk 1326.
#   -> Starting API call for chunk 1382...
#   <- Success on chunk 1336.
#   -> Starting API call for chunk 1383...
#   <- Success on chunk 1346.
#   -> Starting API call for chunk 1384...
#   <- Success on chunk 1287.
#   -> Starting API call for chunk 1385...
#   <- Success on chunk 1339.
#   -> Starting API call for chunk 1386...
#   <- Success on chunk 1352.
#   -> Starting API call for chunk 1387...
#   <- Success on chunk 1341.
#   -> Starting API call for chunk 1388...
#   <- Success on chunk 1348.
#   -> Starting API call for chunk 1389...
#   <- Success on chunk 1307.
#   -> Starting API call for chunk 1390...
#   <- Success on chunk 1344.
#   -> Starting API call for chunk 1391...
#   <- Success on chunk 1343.
#   -> Starting API call for chunk 1392...
#   <- Success on chunk 1349.
#   -> Starting API call for chunk 1393...
#   <- Success on chunk 1351.
#   -> Starting API call for chunk 1394...
#   <- Success on chunk 1353.
#   -> Starting API call for chunk 1395...
#   <- Success on chunk 1354.
#   -> Starting API call for chunk 1396...
#   <- Success on chunk 1340.
#   -> Starting API call for chunk 1397...
#   <- Success on chunk 1345.
#   -> Starting API call for chunk 1398...
#   <- Success on chunk 1363.
#   -> Starting API call for chunk 1399...
#   <- Success on chunk 1338.
#   -> Starting API call for chunk 1400...
#   <- Success on chunk 1360.
#   -> Starting API call for chunk 1401...
#   <- Success on chunk 1347.
#   -> Starting API call for chunk 1402...
#   <- Success on chunk 1367.
#   -> Starting API call for chunk 1403...
#   <- Success on chunk 1355.
#   -> Starting API call for chunk 1404...
#   <- Success on chunk 1364.
#   -> Starting API call for chunk 1405...
#   <- Success on chunk 1358.
#   -> Starting API call for chunk 1406...
#   <- Success on chunk 1377.
#   -> Starting API call for chunk 1407...
#   <- Success on chunk 1368.
#   -> Starting API call for chunk 1408...
#   <- Success on chunk 1365.
#   -> Starting API call for chunk 1409...
#   <- Success on chunk 1317.
#   -> Starting API call for chunk 1410...
#   <- Success on chunk 1370.
#   -> Starting API call for chunk 1411...
#   <- Success on chunk 1359.
#   -> Starting API call for chunk 1412...
#   <- Success on chunk 1312.
#   -> Starting API call for chunk 1413...
#   <- Success on chunk 1372.
#   -> Starting API call for chunk 1414...
#   <- Success on chunk 1357.
#   -> Starting API call for chunk 1415...
#   <- Success on chunk 1376.
#   -> Starting API call for chunk 1416...
#   <- Success on chunk 1356.
#   -> Starting API call for chunk 1417...
#   <- Success on chunk 1361.
#   -> Starting API call for chunk 1418...
#   <- Success on chunk 1374.
#   -> Starting API call for chunk 1419...
#   <- Success on chunk 1362.
#   -> Starting API call for chunk 1420...
#   <- Success on chunk 1381.
#   -> Starting API call for chunk 1421...
#   <- Success on chunk 1371.
#   -> Starting API call for chunk 1422...
#   <- Success on chunk 1379.
#   -> Starting API call for chunk 1423...
#   <- Success on chunk 1369.
#   -> Starting API call for chunk 1424...
#   <- Success on chunk 1301.
#   -> Starting API call for chunk 1425...
#   <- Success on chunk 1350.
#   -> Starting API call for chunk 1426...
#   <- Success on chunk 1373.
#   -> Starting API call for chunk 1427...
#   <- Success on chunk 1382.
#   -> Starting API call for chunk 1428...
#   <- Success on chunk 1388.
#   -> Starting API call for chunk 1429...
#   <- Success on chunk 1402.
#   -> Starting API call for chunk 1430...
#   <- Success on chunk 1406.
#   -> Starting API call for chunk 1431...
#   <- Success on chunk 1383.
#   -> Starting API call for chunk 1432...
#   <- Success on chunk 1378.
#   -> Starting API call for chunk 1433...
#   <- Success on chunk 1390.
#   -> Starting API call for chunk 1434...
#   <- Success on chunk 1385.
#   -> Starting API call for chunk 1435...
#   <- Success on chunk 1386.
#   -> Starting API call for chunk 1436...
#   <- Success on chunk 1391.
#   -> Starting API call for chunk 1437...
#   <- Success on chunk 1401.
#   -> Starting API call for chunk 1438...
#   <- Success on chunk 1375.
#   -> Starting API call for chunk 1439...
#   <- Success on chunk 1400.
#   -> Starting API call for chunk 1440...
#   <- Success on chunk 1394.
#   -> Starting API call for chunk 1441...
#   <- Success on chunk 1384.
#   -> Starting API call for chunk 1442...
#   <- Success on chunk 1397.
#   -> Starting API call for chunk 1443...
#   <- Success on chunk 1395.
#   -> Starting API call for chunk 1444...
#   <- Success on chunk 1399.
#   -> Starting API call for chunk 1445...
#   <- Success on chunk 1393.
#   -> Starting API call for chunk 1446...
#   <- Success on chunk 1398.
#   -> Starting API call for chunk 1447...
#   <- Success on chunk 1396.
#   -> Starting API call for chunk 1448...
#   <- Success on chunk 1380.
#   -> Starting API call for chunk 1449...
#   <- Success on chunk 1387.
#   -> Starting API call for chunk 1450...
#   <- Success on chunk 1403.
#   -> Starting API call for chunk 1451...
#   <- Success on chunk 1412.
#   -> Starting API call for chunk 1452...
#   <- Success on chunk 1404.
#   -> Starting API call for chunk 1453...
#   <- Success on chunk 1416.
#   -> Starting API call for chunk 1454...
#   <- Success on chunk 1405.
#   -> Starting API call for chunk 1455...
#   <- Success on chunk 1419.
#   -> Starting API call for chunk 1456...
#   <- Success on chunk 1410.
#   -> Starting API call for chunk 1457...
#   <- Success on chunk 1408.
#   -> Starting API call for chunk 1458...
#   <- Success on chunk 1417.
#   -> Starting API call for chunk 1459...
#   <- Success on chunk 1420.
#   -> Starting API call for chunk 1460...
#   <- Success on chunk 1407.
#   -> Starting API call for chunk 1461...
#   <- Success on chunk 1389.
#   -> Starting API call for chunk 1462...
#   <- Success on chunk 1443.
#   -> Starting API call for chunk 1463...
#   <- Success on chunk 1411.
#   -> Starting API call for chunk 1464...
#   <- Success on chunk 1445.
#   -> Starting API call for chunk 1465...
#   <- Success on chunk 1418.
#   -> Starting API call for chunk 1466...
#   <- Success on chunk 1428.
#   -> Starting API call for chunk 1467...
#   <- Success on chunk 1413.
#   -> Starting API call for chunk 1468...
#   <- Success on chunk 1414.
#   -> Starting API call for chunk 1469...
#   <- Success on chunk 1423.
#   -> Starting API call for chunk 1470...
#   <- Success on chunk 1425.
#   -> Starting API call for chunk 1471...
#   <- Success on chunk 1426.
#   -> Starting API call for chunk 1472...
#   <- Success on chunk 1434.
#   -> Starting API call for chunk 1473...
#   <- Success on chunk 1409.
#   -> Starting API call for chunk 1474...
#   <- Success on chunk 1427.
#   -> Starting API call for chunk 1475...
#   <- Success on chunk 1429.
#   -> Starting API call for chunk 1476...
#   <- Success on chunk 1415.
#   -> Starting API call for chunk 1477...
#   <- Success on chunk 1431.
#   -> Starting API call for chunk 1478...
#   <- Success on chunk 1438.
#   -> Starting API call for chunk 1479...
#   <- Success on chunk 1447.
#   -> Starting API call for chunk 1480...
#   <- Success on chunk 1440.
#   -> Starting API call for chunk 1481...
#   <- Success on chunk 1430.
#   -> Starting API call for chunk 1482...
#   <- Success on chunk 1422.
#   -> Starting API call for chunk 1483...
#   <- Success on chunk 1421.
#   -> Starting API call for chunk 1484...
#   <- Success on chunk 1366.
#   -> Starting API call for chunk 1485...
#   <- Success on chunk 1435.
#   -> Starting API call for chunk 1486...
#   <- Success on chunk 1433.
#   -> Starting API call for chunk 1487...
#   <- Success on chunk 1437.
#   -> Starting API call for chunk 1488...
#   <- Success on chunk 1453.
#   -> Starting API call for chunk 1489...
#   <- Success on chunk 1444.
#   -> Starting API call for chunk 1490...
#   <- Success on chunk 1436.
#   -> Starting API call for chunk 1491...
#   <- Success on chunk 1449.
#   -> Starting API call for chunk 1492...
#   <- Success on chunk 1442.
#   -> Starting API call for chunk 1493...
#   <- Success on chunk 1392.
#   -> Starting API call for chunk 1494...
#   <- Success on chunk 1466.
#   -> Starting API call for chunk 1495...
#   <- Success on chunk 1450.
#   -> Starting API call for chunk 1496...
#   <- Success on chunk 1462.
#   -> Starting API call for chunk 1497...
#   <- Success on chunk 1457.
#   -> Starting API call for chunk 1498...
#   <- Success on chunk 1432.
#   -> Starting API call for chunk 1499...
#   <- Success on chunk 1459.
#   -> Starting API call for chunk 1500...
#   <- Success on chunk 1469.
#   -> Starting API call for chunk 1501...
#   <- Success on chunk 1458.
#   -> Starting API call for chunk 1502...
#   <- Success on chunk 1452.
#   -> Starting API call for chunk 1503...
#   <- Success on chunk 1471.
#   -> Starting API call for chunk 1504...
#   <- Success on chunk 1467.
#   -> Starting API call for chunk 1505...
#   <- Success on chunk 1448.
#   -> Starting API call for chunk 1506...
#   <- Success on chunk 1439.
#   -> Starting API call for chunk 1507...
#   <- Success on chunk 1424.
#   -> Starting API call for chunk 1508...
#   <- Success on chunk 1468.
#   -> Starting API call for chunk 1509...
#   <- Success on chunk 1456.
#   -> Starting API call for chunk 1510...
#   <- Success on chunk 1461.
#   -> Starting API call for chunk 1511...
#   <- Success on chunk 1455.
#   -> Starting API call for chunk 1512...
#   <- Success on chunk 1446.
#   -> Starting API call for chunk 1513...
#   <- Success on chunk 1478.
#   -> Starting API call for chunk 1514...
#   <- Success on chunk 1465.
#   -> Starting API call for chunk 1515...
#   <- Success on chunk 1451.
#   -> Starting API call for chunk 1516...
#   <- Success on chunk 1475.
#   -> Starting API call for chunk 1517...
#   <- Success on chunk 1489.
#   -> Starting API call for chunk 1518...
#   <- Success on chunk 1483.
#   -> Starting API call for chunk 1519...
#   <- Success on chunk 1473.
#   -> Starting API call for chunk 1520...
#   <- Success on chunk 1484.
#   <- Success on chunk 1454.
#   <- Success on chunk 1496.
#   <- Success on chunk 1487.
#   <- Success on chunk 1470.
#   <- Success on chunk 1472.
#   <- Success on chunk 1503.
#   <- Success on chunk 1486.
#   <- Success on chunk 1479.
#   <- Success on chunk 1476.
#   <- Success on chunk 1474.
#   <- Success on chunk 1491.
#   <- Success on chunk 1488.
#   <- Success on chunk 1441.
#   <- Success on chunk 1481.
#   <- Success on chunk 1463.
#   <- Success on chunk 1498.
#   <- Success on chunk 1505.
#   <- Success on chunk 1509.
#   <- Success on chunk 1485.
#   <- Success on chunk 1494.
#   <- Success on chunk 1497.
#   <- Success on chunk 1464.
#   <- Success on chunk 1495.
#   <- Success on chunk 1480.
#   <- Success on chunk 1512.
#   <- Success on chunk 1499.
#   <- Success on chunk 1492.
#   <- Success on chunk 1490.
#   <- Success on chunk 1493.
#   <- Success on chunk 1510.
#   <- Success on chunk 1482.
#   <- Success on chunk 1501.
#   <- Success on chunk 1500.
#   <- Success on chunk 1513.
#   <- Success on chunk 1504.
#   <- Success on chunk 1516.
#   <- Success on chunk 1502.
#   <- Success on chunk 1508.
#   <- Success on chunk 1506.
#   <- Success on chunk 1520.
#   <- Success on chunk 1507.
#   <- Success on chunk 1477.
#   <- Success on chunk 1518.
#   <- Success on chunk 1514.
#   <- Success on chunk 1511.
#   <- Success on chunk 1519.
#   <- Success on chunk 1460.
#   <- Success on chunk 1517.
#   <- Success on chunk 1515.
